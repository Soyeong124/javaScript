# %% [markdown]
# # Word2Vec 모델을 통해 증상별 질병 찾기

# %% [markdown]
# # 관련 모듈 설치

# %%
pip install pandas
# Out:
# Collecting pandasNote: you may need to restart the kernel to use updated packages.
#
#   Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\miniconda3\envs\ml1\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\miniconda3\envs\ml1\lib\site-packages (from pandas) (2024.1)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\miniconda3\envs\ml1\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB 1.9 MB/s eta 0:00:06
#    - -------------------------------------- 0.5/11.5 MB 7.6 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.5 MB 8.8 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.5 MB 6.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.5/11.5 MB 7.3 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/11.5 MB 8.0 MB/s eta 0:00:02
#    -------- ------------------------------- 2.5/11.5 MB 8.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.0/11.5 MB 8.7 MB/s eta 0:00:01
#    ------------ --------------------------- 3.5/11.5 MB 9.0 MB/s eta 0:00:01
#    ------------- -------------------------- 3.9/11.5 MB 9.0 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.5 MB 9.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.0/11.5 MB 9.4 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.5 MB 9.8 MB/s eta 0:00:01
#    --------------------- ------------------ 6.1/11.5 MB 9.9 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.5 MB 10.0 MB/s eta 0:00:01
#    --------------------- ------------------ 6.3/11.5 MB 10.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.4/11.5 MB 8.5 MB/s eta 0:00:01
#    ------------------------ --------------- 6.9/11.5 MB 8.7 MB/s eta 0:00:01
#    ------------------------- -------------- 7.5/11.5 MB 8.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.0/11.5 MB 9.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.6/11.5 MB 9.1 MB/s eta 0:00:01
#    ------------------------------- -------- 9.0/11.5 MB 9.3 MB/s eta 0:00:01
#    --------------------------------- ------ 9.6/11.5 MB 9.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.1/11.5 MB 9.5 MB/s eta 0:00:01
#    ------------------------------------ --- 10.6/11.5 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 11.1/11.5 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  11.5/11.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 9.8 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 10.8 MB/s eta 0:00:00
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.26.4 pandas-2.2.2 tzdata-2024.1

# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\user\miniconda3\envs\ml1\lib\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\users\user\miniconda3\envs\ml1\lib\site-packages (24.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: setuptools in c:\users\user\miniconda3\envs\ml1\lib\site-packages (69.5.1)
# Requirement already satisfied: wheel in c:\users\user\miniconda3\envs\ml1\lib\site-packages (0.43.0)

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Using cached konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting lxml>=4.1.0 (from konlpy)
#   Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\miniconda3\envs\ml1\lib\site-packages (from konlpy) (1.26.4)
# Requirement already satisfied: packaging in c:\users\user\miniconda3\envs\ml1\lib\site-packages (from JPype1>=0.7.0->konlpy) (23.2)
# Using cached konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
# Downloading JPype1-1.5.0-cp312-cp312-win_amd64.whl (352 kB)
#    ---------------------------------------- 0.0/352.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/352.2 kB ? eta -:--:--
#    ---- ---------------------------------- 41.0/352.2 kB 495.5 kB/s eta 0:00:01
#    ---------------------------------------  348.2/352.2 kB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 352.2/352.2 kB 3.1 MB/s eta 0:00:00
# Downloading lxml-5.2.1-cp312-cp312-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 11.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/3.8 MB 10.7 MB/s eta 0:00:01
#    --------------- ------------------------ 1.5/3.8 MB 10.6 MB/s eta 0:00:01
#    --------------------- ------------------ 2.0/3.8 MB 10.8 MB/s eta 0:00:01
#    -------------------------- ------------- 2.5/3.8 MB 11.6 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------- -- 3.5/3.8 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 10.2 MB/s eta 0:00:00
# Installing collected packages: lxml, JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0 lxml-5.2.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 관련 모듈 임포트

# %%
# from gensim.models import Word2Vec
import pandas as pd
# from gensim.models import Word2Vec
# from konlpy.tag import Okt  # 한국어 처리를 위한 konlpy 라이브러리
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # from gensim.models import Word2Vec
# ----> 2 import pandas as pd
#       3 # from gensim.models import Word2Vec
#       4 # from konlpy.tag import Okt  # 한국어 처리를 위한 konlpy 라이브러리
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # 데이터 준비

# %%
from gensim.models import Word2Vec
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from gensim.models import Word2Vec
#
# File ~\miniconda3\envs\sele1\lib\site-packages\gensim\__init__.py:11
#       7 __version__ = '4.3.2'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~\miniconda3\envs\sele1\lib\site-packages\gensim\corpora\__init__.py:6
#       1 """
#       2 This package contains implementations of various streaming corpus I/O format.
#       3 """
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       8 from .mmcorpus import MmCorpus  # noqa:F401
#       9 from .bleicorpus import BleiCorpus  # noqa:F401
#
# File ~\miniconda3\envs\sele1\lib\site-packages\gensim\corpora\indexedcorpus.py:14
#      10 import logging
#      12 import numpy
# ---> 14 from gensim import interfaces, utils
#      16 logger = logging.getLogger(__name__)
#      19 class IndexedCorpus(interfaces.CorpusABC):
#
# File ~\miniconda3\envs\sele1\lib\site-packages\gensim\interfaces.py:19
#       7 """Basic interfaces used across the whole Gensim package.
#       8
#       9 These interfaces are used for building corpora, model transformation and similarity queries.
#    (...)
#      14
#      15 """
#      17 import logging
# ---> 19 from gensim import utils, matutils
#      22 logger = logging.getLogger(__name__)
#      25 class CorpusABC(utils.SaveLoad):
#
# File ~\miniconda3\envs\sele1\lib\site-packages\gensim\matutils.py:20
#      18 import scipy.sparse
#      19 from scipy.stats import entropy
# ---> 20 from scipy.linalg import get_blas_funcs, triu
#      21 from scipy.linalg.lapack import get_lapack_funcs
#      22 from scipy.special import psi  # gamma function utils
#
# ImportError: cannot import name 'triu' from 'scipy.linalg' (C:\Users\user\miniconda3\envs\sele1\lib\site-packages\scipy\linalg\__init__.py)

# %%
# CSV 파일 경로
file_path = '../Model/Data/diseases_240510.csv'

# CSV 파일 읽기
df = pd.read_csv(file_path)
df = df.dropna(subset=['symptoms'])

# 결과를 담을 리스트 초기화
result_lists = []

# 각 행(질병)에 대해 반복
for index, row in df.iterrows():
    disease_name = row['disease_name']
    symptoms = row['symptoms'].split(', ')
    
    # 수정된 부분: 첫 번째 형식의 리스트 생성
    list1 = []
    for symptom in symptoms:
        list1.extend([disease_name, symptom])
    
    # 두 번째 형식의 리스트 생성
    list2 = [disease_name] + symptoms
    
    # 결과 리스트에 추가
    result_lists.append(list1)
    result_lists.append(list2)

# %%
result_lists
# Out:
# [['RS바이러스 감염증(RS virus infection)',
#   '기침',
#   'RS바이러스 감염증(RS virus infection)',
#   '가래',
#   'RS바이러스 감염증(RS virus infection)',
#   '열',
#   'RS바이러스 감염증(RS virus infection)',
#   '빈호흡',
#   'RS바이러스 감염증(RS virus infection)',
#   '콧물',
#   'RS바이러스 감염증(RS virus infection)',
#   '코막힘',
#   'RS바이러스 감염증(RS virus infection)',
#   '청색증'],
#  ['RS바이러스 감염증(RS virus infection)',
#   '기침',
#   '가래',
#   '열',
#   '빈호흡',
#   '콧물',
#   '코막힘',
#   '청색증'],
#  ['각막염(Keratitis)',
#   '안구혼탁',
#   '각막염(Keratitis)',
#   '눈의 충혈',
#   '각막염(Keratitis)',
#   '눈물흘림',
#   '각막염(Keratitis)',
#   '눈의 통증',
#   '각막염(Keratitis)',
#   '시력 감소',
#   '각막염(Keratitis)',
#   '눈부심'],
#  ['각막염(Keratitis)', '안구혼탁', '눈의 충혈', '눈물흘림', '눈의 통증', '시력 감소', '눈부심'],
#  ['간농양(Liver abscess)',
#   '황달',
#   '간농양(Liver abscess)',
#   '기운없음',
#   '간농양(Liver abscess)',
#   '오한',
#   '간농양(Liver abscess)',
#   '열',
#   '간농양(Liver abscess)',
#   '복부 통증',
#   '간농양(Liver abscess)',
#   '오심',
#   '간농양(Liver abscess)',
#   '설사',
#   '간농양(Liver abscess)',
#   '압통',
#   '간농양(Liver abscess)',
#   '구토',
#   '간농양(Liver abscess)',
#   '간비대'],
#  ['간농양(Liver abscess)',
#   '황달',
#   '기운없음',
#   '오한',
#   '열',
#   '복부 통증',
#   '오심',
#   '설사',
#   '압통',
#   '구토',
#   '간비대'],
#  ['감염성 근육염(Infective myositis)',
#   '피부염증',
#   '감염성 근육염(Infective myositis)',
#   '발진',
#   '감염성 근육염(Infective myositis)',
#   '열감',
#   '감염성 근육염(Infective myositis)',
#   '압통',
#   '감염성 근육염(Infective myositis)',
#   '환부 부종'],
#  ['감염성 근육염(Infective myositis)', '피부염증', '발진', '열감', '압통', '환부 부종'],
#  ['감염성 단핵구증(Infectious mononucleosis)',
#   '열',
#   '감염성 단핵구증(Infectious mononucleosis)',
#   '목의 통증',
#   '감염성 단핵구증(Infectious mononucleosis)',
#   '열감',
#   '감염성 단핵구증(Infectious mononucleosis)',
#   '삼키기 곤란',
#   '감염성 단핵구증(Infectious mononucleosis)',
#   '오한',
#   '감염성 단핵구증(Infectious mononucleosis)',
#   '기운없음',
#   '감염성 단핵구증(Infectious mononucleosis)',
#   '압통',
#   '감염성 단핵구증(Infectious mononucleosis)',
#   '발진'],
#  ['감염성 단핵구증(Infectious mononucleosis)',
#   '열',
#   '목의 통증',
#   '열감',
#   '삼키기 곤란',
#   '오한',
#   '기운없음',
#   '압통',
#   '발진'],
#  ['감염성 홍반(Erythema infectiosum)',
#   '두통',
#   '감염성 홍반(Erythema infectiosum)',
#   '안면홍조',
#   '감염성 홍반(Erythema infectiosum)',
#   '열',
#   '감염성 홍반(Erythema infectiosum)',
#   '권태감',
#   '감염성 홍반(Erythema infectiosum)',
#   '식욕부진'],
#  ['감염성 홍반(Erythema infectiosum)', '두통', '안면홍조', '열', '권태감', '식욕부진'],
#  ['거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '열',
#   '거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '정신 지체',
#   '거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '태아 저체중',
#   '거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '무증상',
#   '거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '청력장애',
#   '거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '난청',
#   '거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '궤양',
#   '거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '피로감'],
#  ['거대세포 바이러스 질환(Cytomegaloviral diseases)',
#   '열',
#   '정신 지체',
#   '태아 저체중',
#   '무증상',
#   '청력장애',
#   '난청',
#   '궤양',
#   '피로감'],
#  ['결막염(Conjunctivitis)',
#   '눈꼽',
#   '결막염(Conjunctivitis)',
#   '눈의 자극감',
#   '결막염(Conjunctivitis)',
#   '눈부심',
#   '결막염(Conjunctivitis)',
#   '눈의 피로',
#   '결막염(Conjunctivitis)',
#   '눈의 충혈'],
#  ['결막염(Conjunctivitis)', '눈꼽', '눈의 자극감', '눈부심', '눈의 피로', '눈의 충혈'],
#  ['결핵(Tuberculosis)',
#   '열',
#   '결핵(Tuberculosis)',
#   '객혈',
#   '결핵(Tuberculosis)',
#   '체중감소',
#   '결핵(Tuberculosis)',
#   '기침',
#   '결핵(Tuberculosis)',
#   '가래'],
#  ['결핵(Tuberculosis)', '열', '객혈', '체중감소', '기침', '가래'],
#  ['결핵성 골수염(Tuberculous osteomyelitis)',
#   '식욕부진',
#   '결핵성 골수염(Tuberculous osteomyelitis)',
#   '근육경련',
#   '결핵성 골수염(Tuberculous osteomyelitis)',
#   '뼈의 변형',
#   '결핵성 골수염(Tuberculous osteomyelitis)',
#   '관절통',
#   '결핵성 골수염(Tuberculous osteomyelitis)',
#   '체중감소',
#   '결핵성 골수염(Tuberculous osteomyelitis)',
#   '열'],
#  ['결핵성 골수염(Tuberculous osteomyelitis)',
#   '식욕부진',
#   '근육경련',
#   '뼈의 변형',
#   '관절통',
#   '체중감소',
#   '열'],
#  ['결핵성 복막염(Tuberculous peritonitis)',
#   '복부팽만감',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '오심',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '복부 통증',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '열',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '권태감',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '빈호흡',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '빈맥',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '체중감소',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '발한',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '압통',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '복수',
#   '결핵성 복막염(Tuberculous peritonitis)',
#   '식욕부진'],
#  ['결핵성 복막염(Tuberculous peritonitis)',
#   '복부팽만감',
#   '오심',
#   '복부 통증',
#   '열',
#   '권태감',
#   '빈호흡',
#   '빈맥',
#   '체중감소',
#   '발한',
#   '압통',
#   '복수',
#   '식욕부진'],
#  ['결핵성 수막염(Tuberculous meningitis)',
#   '두통',
#   '결핵성 수막염(Tuberculous meningitis)',
#   '시야장애',
#   '결핵성 수막염(Tuberculous meningitis)',
#   '열',
#   '결핵성 수막염(Tuberculous meningitis)',
#   '눈운동신경마비',
#   '결핵성 수막염(Tuberculous meningitis)',
#   '혼수',
#   '결핵성 수막염(Tuberculous meningitis)',
#   '졸림'],
#  ['결핵성 수막염(Tuberculous meningitis)', '두통', '시야장애', '열', '눈운동신경마비', '혼수', '졸림'],
#  ['결핵성 임파선염(Tuberculous lymphadenitis)',
#   '목 주변 부종',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '피로감',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '체중감소',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '열',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '고름',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '발한',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '피부궤양',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '목의 통증',
#   '결핵성 임파선염(Tuberculous lymphadenitis)',
#   '식욕부진'],
#  ['결핵성 임파선염(Tuberculous lymphadenitis)',
#   '목 주변 부종',
#   '피로감',
#   '체중감소',
#   '열',
#   '고름',
#   '발한',
#   '피부궤양',
#   '목의 통증',
#   '식욕부진'],
#  ['경부 림프절염(Cervical lymphadenitis)',
#   '통증 없는 부종',
#   '경부 림프절염(Cervical lymphadenitis)',
#   '압통',
#   '경부 림프절염(Cervical lymphadenitis)',
#   '열'],
#  ['경부 림프절염(Cervical lymphadenitis)', '통증 없는 부종', '압통', '열'],
#  ['곰팡이 감염(Fungal infection)',
#   '발가락 사이 갈라짐',
#   '곰팡이 감염(Fungal infection)',
#   '손,발톱이 갈라짐',
#   '곰팡이 감염(Fungal infection)',
#   '피부 각질',
#   '곰팡이 감염(Fungal infection)',
#   '피부소양감'],
#  ['곰팡이 감염(Fungal infection)', '발가락 사이 갈라짐', '손,발톱이 갈라짐', '피부 각질', '피부소양감'],
#  ['광견병(Rabies)',
#   '혼수',
#   '광견병(Rabies)',
#   '열',
#   '광견병(Rabies)',
#   '뇌염증상',
#   '광견병(Rabies)',
#   '뇌전증 발작',
#   '광견병(Rabies)',
#   '호흡곤란',
#   '광견병(Rabies)',
#   '구토',
#   '광견병(Rabies)',
#   '근육강직',
#   '광견병(Rabies)',
#   '두통'],
#  ['광견병(Rabies)', '혼수', '열', '뇌염증상', '뇌전증 발작', '호흡곤란', '구토', '근육강직', '두통'],
#  ['광우병(Bovine spongiform encephalopathy)',
#   '치매',
#   '광우병(Bovine spongiform encephalopathy)',
#   '정신 지체',
#   '광우병(Bovine spongiform encephalopathy)',
#   '이상행동',
#   '광우병(Bovine spongiform encephalopathy)',
#   '기억장애'],
#  ['광우병(Bovine spongiform encephalopathy)', '치매', '정신 지체', '이상행동', '기억장애'],
#  ['구순염(Cheilitis)',
#   '입 주변 부종',
#   '구순염(Cheilitis)',
#   '입술 갈라짐',
#   '구순염(Cheilitis)',
#   '소양감'],
#  ['구순염(Cheilitis)', '입 주변 부종', '입술 갈라짐', '소양감'],
#  ['구순포진(Herpes labialis)',
#   '작열감',
#   '구순포진(Herpes labialis)',
#   '물집',
#   '구순포진(Herpes labialis)',
#   '소양감',
#   '구순포진(Herpes labialis)',
#   '피부색 변화'],
#  ['구순포진(Herpes labialis)', '작열감', '물집', '소양감', '피부색 변화'],
#  ['급성 바이러스성 간염(Acute viral hepatitis)',
#   '황달',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '근육통',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '감기 증상',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '식욕부진',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '권태감',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '피로감',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '구토',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '피부소양감',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '관절통',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '피부 긴장도 저하',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '오심',
#   '급성 바이러스성 간염(Acute viral hepatitis)',
#   '복부 통증'],
#  ['급성 바이러스성 간염(Acute viral hepatitis)',
#   '황달',
#   '근육통',
#   '감기 증상',
#   '식욕부진',
#   '권태감',
#   '피로감',
#   '구토',
#   '피부소양감',
#   '관절통',
#   '피부 긴장도 저하',
#   '오심',
#   '복부 통증'],
#  ['급성 위장염(Acute gastroenteritis)',
#   '복부 통증',
#   '급성 위장염(Acute gastroenteritis)',
#   '열',
#   '급성 위장염(Acute gastroenteritis)',
#   '구토',
#   '급성 위장염(Acute gastroenteritis)',
#   '설사',
#   '급성 위장염(Acute gastroenteritis)',
#   '탈수',
#   '급성 위장염(Acute gastroenteritis)',
#   '두통',
#   '급성 위장염(Acute gastroenteritis)',
#   '복부팽만감'],
#  ['급성 위장염(Acute gastroenteritis)',
#   '복부 통증',
#   '열',
#   '구토',
#   '설사',
#   '탈수',
#   '두통',
#   '복부팽만감'],
#  ['급성 질염(Acute vaginitis)',
#   '악취',
#   '급성 질염(Acute vaginitis)',
#   '배뇨곤란',
#   '급성 질염(Acute vaginitis)',
#   '비정상적 질 분비물',
#   '급성 질염(Acute vaginitis)',
#   '소양감',
#   '급성 질염(Acute vaginitis)',
#   '작열감',
#   '급성 질염(Acute vaginitis)',
#   '배뇨 시 통증'],
#  ['급성 질염(Acute vaginitis)',
#   '악취',
#   '배뇨곤란',
#   '비정상적 질 분비물',
#   '소양감',
#   '작열감',
#   '배뇨 시 통증'],
#  ['기쿠치병(Kikuchi Disease)',
#   '발진',
#   '기쿠치병(Kikuchi Disease)',
#   '관절통',
#   '기쿠치병(Kikuchi Disease)',
#   '피로감',
#   '기쿠치병(Kikuchi Disease)',
#   '체중감소',
#   '기쿠치병(Kikuchi Disease)',
#   '식욕부진',
#   '기쿠치병(Kikuchi Disease)',
#   '열',
#   '기쿠치병(Kikuchi Disease)',
#   '경부 림프절병증'],
#  ['기쿠치병(Kikuchi Disease)',
#   '발진',
#   '관절통',
#   '피로감',
#   '체중감소',
#   '식욕부진',
#   '열',
#   '경부 림프절병증'],
#  ['난소난관염(Oophoritis, Ovaritis)',
#   '비정상적 질출혈',
#   '난소난관염(Oophoritis, Ovaritis)',
#   '복부 통증',
#   '난소난관염(Oophoritis, Ovaritis)',
#   '열',
#   '난소난관염(Oophoritis, Ovaritis)',
#   '비정상적 질 분비물'],
#  ['난소난관염(Oophoritis, Ovaritis)', '비정상적 질출혈', '복부 통증', '열', '비정상적 질 분비물'],
#  ['노로바이러스 장염(Norovirus Gastroenteritis)',
#   '오심',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '복부 통증',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '설사',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '근육통',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '오한',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '권태감',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '두통',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '열',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '구토',
#   '노로바이러스 장염(Norovirus Gastroenteritis)',
#   '복부 불편감'],
#  ['노로바이러스 장염(Norovirus Gastroenteritis)',
#   '오심',
#   '복부 통증',
#   '설사',
#   '근육통',
#   '오한',
#   '권태감',
#   '두통',
#   '열',
#   '구토',
#   '복부 불편감'],
#  ['노카르디아증(Nocardiosis)',
#   '열',
#   '노카르디아증(Nocardiosis)',
#   '기침',
#   '노카르디아증(Nocardiosis)',
#   '체중감소',
#   '노카르디아증(Nocardiosis)',
#   '객혈'],
#  ['노카르디아증(Nocardiosis)', '열', '기침', '체중감소', '객혈'],
#  ['뇌농양(Brain abscess)',
#   '오심',
#   '뇌농양(Brain abscess)',
#   '구토',
#   '뇌농양(Brain abscess)',
#   '열',
#   '뇌농양(Brain abscess)',
#   '경련',
#   '뇌농양(Brain abscess)',
#   '성격의변화',
#   '뇌농양(Brain abscess)',
#   '두통'],
#  ['뇌농양(Brain abscess)', '오심', '구토', '열', '경련', '성격의변화', '두통'],
#  ['뇌염(Encephalitis)',
#   '시력 감소',
#   '뇌염(Encephalitis)',
#   '오한',
#   '뇌염(Encephalitis)',
#   '경련',
#   '뇌염(Encephalitis)',
#   '경부 강직',
#   '뇌염(Encephalitis)',
#   '두통',
#   '뇌염(Encephalitis)',
#   '기운없음',
#   '뇌염(Encephalitis)',
#   '구토',
#   '뇌염(Encephalitis)',
#   '정신 혼미',
#   '뇌염(Encephalitis)',
#   '의식 저하',
#   '뇌염(Encephalitis)',
#   '방향감각 상실',
#   '뇌염(Encephalitis)',
#   '열'],
#  ['뇌염(Encephalitis)',
#   '시력 감소',
#   '오한',
#   '경련',
#   '경부 강직',
#   '두통',
#   '기운없음',
#   '구토',
#   '정신 혼미',
#   '의식 저하',
#   '방향감각 상실',
#   '열'],
#  ['단독(Erysipelas)',
#   '림프 부종',
#   '단독(Erysipelas)',
#   '열감',
#   '단독(Erysipelas)',
#   '오한',
#   '단독(Erysipelas)',
#   '발진',
#   '단독(Erysipelas)',
#   '환부 통증'],
#  ['단독(Erysipelas)', '림프 부종', '열감', '오한', '발진', '환부 통증'],
#  ['단순 포진(Herpes Simplex)',
#   '작열감',
#   '단순 포진(Herpes Simplex)',
#   '물집',
#   '단순 포진(Herpes Simplex)',
#   '소양감'],
#  ['단순 포진(Herpes Simplex)', '작열감', '물집', '소양감'],
#  ['단순 포진성 뇌염(Herpes simplex encephalitis)',
#   '뇌전증 발작',
#   '단순 포진성 뇌염(Herpes simplex encephalitis)',
#   '의식 변화',
#   '단순 포진성 뇌염(Herpes simplex encephalitis)',
#   '두통',
#   '단순 포진성 뇌염(Herpes simplex encephalitis)',
#   '언어장애',
#   '단순 포진성 뇌염(Herpes simplex encephalitis)',
#   '열'],
#  ['단순 포진성 뇌염(Herpes simplex encephalitis)',
#   '뇌전증 발작',
#   '의식 변화',
#   '두통',
#   '언어장애',
#   '열'],
#  ['대상포진(Herpes zoster)',
#   '두통',
#   '대상포진(Herpes zoster)',
#   '환부 통증',
#   '대상포진(Herpes zoster)',
#   '딱지',
#   '대상포진(Herpes zoster)',
#   '발진'],
#  ['대상포진(Herpes zoster)', '두통', '환부 통증', '딱지', '발진'],
#  ['대상포진 후 신경통(Postzoster neuralgia)', '환부 통증'],
#  ['대상포진 후 신경통(Postzoster neuralgia)', '환부 통증'],
#  ['대장균 감염(Escherichia coli (E. coli) infection)',
#   '구토',
#   '대장균 감염(Escherichia coli (E. coli) infection)',
#   '설사',
#   '대장균 감염(Escherichia coli (E. coli) infection)',
#   '두통',
#   '대장균 감염(Escherichia coli (E. coli) infection)',
#   '복부 통증'],
#  ['대장균 감염(Escherichia coli (E. coli) infection)', '구토', '설사', '두통', '복부 통증'],
#  ['뎅기열(Dengue fever)',
#   '반점',
#   '뎅기열(Dengue fever)',
#   '식욕부진',
#   '뎅기열(Dengue fever)',
#   '발진',
#   '뎅기열(Dengue fever)',
#   '두통',
#   '뎅기열(Dengue fever)',
#   '근육통',
#   '뎅기열(Dengue fever)',
#   '관절통',
#   '뎅기열(Dengue fever)',
#   '열'],
#  ['뎅기열(Dengue fever)', '반점', '식욕부진', '발진', '두통', '근육통', '관절통', '열'],
#  ['돌발성 발진(Exanthem subitum)',
#   '보챔',
#   '돌발성 발진(Exanthem subitum)',
#   '식욕부진',
#   '돌발성 발진(Exanthem subitum)',
#   '발진',
#   '돌발성 발진(Exanthem subitum)',
#   '반점'],
#  ['돌발성 발진(Exanthem subitum)', '보챔', '식욕부진', '발진', '반점'],
#  ['두부 백선(Tinea Capitis)',
#   '피부 각질',
#   '두부 백선(Tinea Capitis)',
#   '체모감소',
#   '두부 백선(Tinea Capitis)',
#   '피부소양감'],
#  ['두부 백선(Tinea Capitis)', '피부 각질', '체모감소', '피부소양감'],
#  ['두통(Headache)',
#   '압통',
#   '두통(Headache)',
#   '눈이 무거운 느낌',
#   '두통(Headache)',
#   '박동성 통증',
#   '두통(Headache)',
#   '뇌압상승증상'],
#  ['두통(Headache)', '압통', '눈이 무거운 느낌', '박동성 통증', '뇌압상승증상'],
#  ['디프테리아(Diphtheritia)',
#   '목의 통증',
#   '디프테리아(Diphtheritia)',
#   '기침',
#   '디프테리아(Diphtheritia)',
#   '열',
#   '디프테리아(Diphtheritia)',
#   '기운없음',
#   '디프테리아(Diphtheritia)',
#   '빈맥',
#   '디프테리아(Diphtheritia)',
#   '콧물'],
#  ['디프테리아(Diphtheritia)', '목의 통증', '기침', '열', '기운없음', '빈맥', '콧물'],
#  ['라싸열(Lassa fever )',
#   '뇌염증상',
#   '라싸열(Lassa fever )',
#   '열',
#   '라싸열(Lassa fever )',
#   '청력장애',
#   '라싸열(Lassa fever )',
#   '가슴 통증',
#   '라싸열(Lassa fever )',
#   '결막염',
#   '라싸열(Lassa fever )',
#   '얼굴부종',
#   '라싸열(Lassa fever )',
#   '구토',
#   '라싸열(Lassa fever )',
#   '단백뇨',
#   '라싸열(Lassa fever )',
#   '근육통'],
#  ['라싸열(Lassa fever )',
#   '뇌염증상',
#   '열',
#   '청력장애',
#   '가슴 통증',
#   '결막염',
#   '얼굴부종',
#   '구토',
#   '단백뇨',
#   '근육통'],
#  ['라임병(Lyme disease)',
#   '관절통',
#   '라임병(Lyme disease)',
#   '오한',
#   '라임병(Lyme disease)',
#   '안구혼탁',
#   '라임병(Lyme disease)',
#   '열',
#   '라임병(Lyme disease)',
#   '피로감',
#   '라임병(Lyme disease)',
#   '근육통',
#   '라임병(Lyme disease)',
#   '두통',
#   '라임병(Lyme disease)',
#   '수면장애',
#   '라임병(Lyme disease)',
#   '발진'],
#  ['라임병(Lyme disease)',
#   '관절통',
#   '오한',
#   '안구혼탁',
#   '열',
#   '피로감',
#   '근육통',
#   '두통',
#   '수면장애',
#   '발진'],
#  ['레지오넬라증(Legionella)',
#   '설사',
#   '레지오넬라증(Legionella)',
#   '두통',
#   '레지오넬라증(Legionella)',
#   '기침',
#   '레지오넬라증(Legionella)',
#   '오한',
#   '레지오넬라증(Legionella)',
#   '오심',
#   '레지오넬라증(Legionella)',
#   '구토',
#   '레지오넬라증(Legionella)',
#   '목의 통증',
#   '레지오넬라증(Legionella)',
#   '근육통',
#   '레지오넬라증(Legionella)',
#   '콧물',
#   '레지오넬라증(Legionella)',
#   '권태감',
#   '레지오넬라증(Legionella)',
#   '열'],
#  ['레지오넬라증(Legionella)',
#   '설사',
#   '두통',
#   '기침',
#   '오한',
#   '오심',
#   '구토',
#   '목의 통증',
#   '근육통',
#   '콧물',
#   '권태감',
#   '열'],
#  ['렙토스피라증(Leptospirosis)',
#   '신부전',
#   '렙토스피라증(Leptospirosis)',
#   '수막자극증상',
#   '렙토스피라증(Leptospirosis)',
#   '두통',
#   '렙토스피라증(Leptospirosis)',
#   '안구내 출혈',
#   '렙토스피라증(Leptospirosis)',
#   '간부전',
#   '렙토스피라증(Leptospirosis)',
#   '열',
#   '렙토스피라증(Leptospirosis)',
#   '오한',
#   '렙토스피라증(Leptospirosis)',
#   '황달',
#   '렙토스피라증(Leptospirosis)',
#   '근육통'],
#  ['렙토스피라증(Leptospirosis)',
#   '신부전',
#   '수막자극증상',
#   '두통',
#   '안구내 출혈',
#   '간부전',
#   '열',
#   '오한',
#   '황달',
#   '근육통'],
#  ['리스테리아(Listeria)',
#   '근육통',
#   '리스테리아(Listeria)',
#   '열',
#   '리스테리아(Listeria)',
#   '설사',
#   '리스테리아(Listeria)',
#   '구토',
#   '리스테리아(Listeria)',
#   '두통'],
#  ['리스테리아(Listeria)', '근육통', '열', '설사', '구토', '두통'],
#  ['마버그열(Marburg hemorrhagic fever)',
#   '근육통',
#   '마버그열(Marburg hemorrhagic fever)',
#   '기침',
#   '마버그열(Marburg hemorrhagic fever)',
#   '두통',
#   '마버그열(Marburg hemorrhagic fever)',
#   '오한',
#   '마버그열(Marburg hemorrhagic fever)',
#   '권태감',
#   '마버그열(Marburg hemorrhagic fever)',
#   '열'],
#  ['마버그열(Marburg hemorrhagic fever)', '근육통', '기침', '두통', '오한', '권태감', '열'],
#  ['만성 C형 간염(Chronic hepatitis C)',
#   '황달',
#   '만성 C형 간염(Chronic hepatitis C)',
#   '무증상',
#   '만성 C형 간염(Chronic hepatitis C)',
#   '복부 불편감',
#   '만성 C형 간염(Chronic hepatitis C)',
#   '소화불량',
#   '만성 C형 간염(Chronic hepatitis C)',
#   '피로감'],
#  ['만성 C형 간염(Chronic hepatitis C)', '황달', '무증상', '복부 불편감', '소화불량', '피로감'],
#  ['말라리아(Malaria)',
#   '식욕부진',
#   '말라리아(Malaria)',
#   '열',
#   '말라리아(Malaria)',
#   '오한',
#   '말라리아(Malaria)',
#   '두통'],
#  ['말라리아(Malaria)', '식욕부진', '열', '오한', '두통'],
#  ['매독(Syphilis)', '무증상'],
#  ['매독(Syphilis)', '무증상'],
#  ['메리오이드증(Melioidosis)',
#   '열',
#   '메리오이드증(Melioidosis)',
#   '오한',
#   '메리오이드증(Melioidosis)',
#   '사망',
#   '메리오이드증(Melioidosis)',
#   '호흡곤란',
#   '메리오이드증(Melioidosis)',
#   '객혈',
#   '메리오이드증(Melioidosis)',
#   '두통',
#   '메리오이드증(Melioidosis)',
#   '권태감',
#   '메리오이드증(Melioidosis)',
#   '근육통',
#   '메리오이드증(Melioidosis)',
#   '기침'],
#  ['메리오이드증(Melioidosis)',
#   '열',
#   '오한',
#   '사망',
#   '호흡곤란',
#   '객혈',
#   '두통',
#   '권태감',
#   '근육통',
#   '기침'],
#  ['무른 궤양(Chancroid)',
#   '림프 부종',
#   '무른 궤양(Chancroid)',
#   '환부의 분비물',
#   '무른 궤양(Chancroid)',
#   '생식기 궤양'],
#  ['무른 궤양(Chancroid)', '림프 부종', '환부의 분비물', '생식기 궤양'],
#  ['바이러스성 뇌수막염(Viral meningitis)',
#   '열',
#   '바이러스성 뇌수막염(Viral meningitis)',
#   '두통',
#   '바이러스성 뇌수막염(Viral meningitis)',
#   '혼수',
#   '바이러스성 뇌수막염(Viral meningitis)',
#   '경련',
#   '바이러스성 뇌수막염(Viral meningitis)',
#   '성격의변화',
#   '바이러스성 뇌수막염(Viral meningitis)',
#   '뇌전증 발작',
#   '바이러스성 뇌수막염(Viral meningitis)',
#   '경부 강직'],
#  ['바이러스성 뇌수막염(Viral meningitis)',
#   '열',
#   '두통',
#   '혼수',
#   '경련',
#   '성격의변화',
#   '뇌전증 발작',
#   '경부 강직'],
#  ['박테리아성 뇌수막염(Bacterial meningitis)',
#   '감기 증상',
#   '박테리아성 뇌수막염(Bacterial meningitis)',
#   '오심',
#   '박테리아성 뇌수막염(Bacterial meningitis)',
#   '열',
#   '박테리아성 뇌수막염(Bacterial meningitis)',
#   '경부 강직',
#   '박테리아성 뇌수막염(Bacterial meningitis)',
#   '경련',
#   '박테리아성 뇌수막염(Bacterial meningitis)',
#   '두통',
#   '박테리아성 뇌수막염(Bacterial meningitis)',
#   '혼수',
#   '박테리아성 뇌수막염(Bacterial meningitis)',
#   '구토'],
#  ['박테리아성 뇌수막염(Bacterial meningitis)',
#   '감기 증상',
#   '오심',
#   '열',
#   '경부 강직',
#   '경련',
#   '두통',
#   '혼수',
#   '구토'],
#  ['반코마이신 내성 장알균(VRE) 감염증(Vancomycin-Resistant Enterococci)',
#   '오한',
#   '반코마이신 내성 장알균(VRE) 감염증(Vancomycin-Resistant Enterococci)',
#   '저혈압',
#   '반코마이신 내성 장알균(VRE) 감염증(Vancomycin-Resistant Enterococci)',
#   '열'],
#  ['반코마이신 내성 장알균(VRE) 감염증(Vancomycin-Resistant Enterococci)', '오한', '저혈압', '열'],
#  ['반코마이신 내성 황색포도알균(VRSA) 감염증(Vancomycin-Resistant Staphylococcus aureus)',
#   '저혈압',
#   '반코마이신 내성 황색포도알균(VRSA) 감염증(Vancomycin-Resistant Staphylococcus aureus)',
#   '열',
#   '반코마이신 내성 황색포도알균(VRSA) 감염증(Vancomycin-Resistant Staphylococcus aureus)',
#   '오한'],
#  ['반코마이신 내성 황색포도알균(VRSA) 감염증(Vancomycin-Resistant Staphylococcus aureus)',
#   '저혈압',
#   '열',
#   '오한'],
#  ['발진열(Murine typhus)',
#   '근육통',
#   '발진열(Murine typhus)',
#   '권태감',
#   '발진열(Murine typhus)',
#   '두통',
#   '발진열(Murine typhus)',
#   '열',
#   '발진열(Murine typhus)',
#   '기침',
#   '발진열(Murine typhus)',
#   '오한'],
#  ['발진열(Murine typhus)', '근육통', '권태감', '두통', '열', '기침', '오한'],
#  ['발진티푸스(Epidemic typhus)',
#   '두통',
#   '발진티푸스(Epidemic typhus)',
#   '근육통',
#   '발진티푸스(Epidemic typhus)',
#   '권태감',
#   '발진티푸스(Epidemic typhus)',
#   '오한',
#   '발진티푸스(Epidemic typhus)',
#   '열'],
#  ['발진티푸스(Epidemic typhus)', '두통', '근육통', '권태감', '오한', '열'],
#  ['방선균증(Actinomycosis)',
#   '발한',
#   '방선균증(Actinomycosis)',
#   '환부 통증',
#   '방선균증(Actinomycosis)',
#   '체중감소',
#   '방선균증(Actinomycosis)',
#   '열감',
#   '방선균증(Actinomycosis)',
#   '두통',
#   '방선균증(Actinomycosis)',
#   '기침',
#   '방선균증(Actinomycosis)',
#   '열'],
#  ['방선균증(Actinomycosis)', '발한', '환부 통증', '체중감소', '열감', '두통', '기침', '열'],
#  ['백일해(Pertussis)',
#   '구토',
#   '백일해(Pertussis)',
#   '콧물',
#   '백일해(Pertussis)',
#   '결막염',
#   '백일해(Pertussis)',
#   '기침'],
#  ['백일해(Pertussis)', '구토', '콧물', '결막염', '기침'],
#  ['베게너 육아종증(Wegener granulomatosis)',
#   '관절염',
#   '베게너 육아종증(Wegener granulomatosis)',
#   '근육통'],
#  ['베게너 육아종증(Wegener granulomatosis)', '관절염', '근육통'],
#  ['병원 감염성 폐렴(Hospital acquired pneumonia (HAP))',
#   '근육통',
#   '병원 감염성 폐렴(Hospital acquired pneumonia (HAP))',
#   '가슴 통증',
#   '병원 감염성 폐렴(Hospital acquired pneumonia (HAP))',
#   '열',
#   '병원 감염성 폐렴(Hospital acquired pneumonia (HAP))',
#   '오한',
#   '병원 감염성 폐렴(Hospital acquired pneumonia (HAP))',
#   '가래',
#   '병원 감염성 폐렴(Hospital acquired pneumonia (HAP))',
#   '기침'],
#  ['병원 감염성 폐렴(Hospital acquired pneumonia (HAP))',
#   '근육통',
#   '가슴 통증',
#   '열',
#   '오한',
#   '가래',
#   '기침'],
#  ['보툴리눔독소증(Botulism)',
#   '복시',
#   '보툴리눔독소증(Botulism)',
#   '호흡곤란',
#   '보툴리눔독소증(Botulism)',
#   '요정체',
#   '보툴리눔독소증(Botulism)',
#   '장폐색',
#   '보툴리눔독소증(Botulism)',
#   '신경 마비',
#   '보툴리눔독소증(Botulism)',
#   '안검하수',
#   '보툴리눔독소증(Botulism)',
#   '시야장애',
#   '보툴리눔독소증(Botulism)',
#   '근육마비',
#   '보툴리눔독소증(Botulism)',
#   '삼키기 곤란'],
#  ['보툴리눔독소증(Botulism)',
#   '복시',
#   '호흡곤란',
#   '요정체',
#   '장폐색',
#   '신경 마비',
#   '안검하수',
#   '시야장애',
#   '근육마비',
#   '삼키기 곤란'],
#  ['브루셀라증(Brucellosis)',
#   '오한',
#   '브루셀라증(Brucellosis)',
#   '열',
#   '브루셀라증(Brucellosis)',
#   '체중감소',
#   '브루셀라증(Brucellosis)',
#   '피로감',
#   '브루셀라증(Brucellosis)',
#   '환부 통증',
#   '브루셀라증(Brucellosis)',
#   '우울',
#   '브루셀라증(Brucellosis)',
#   '두통'],
#  ['브루셀라증(Brucellosis)', '오한', '열', '체중감소', '피로감', '환부 통증', '우울', '두통'],
#  ['비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '물집',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '기운없음',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '오한',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '열',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '저혈압',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '설사',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '환부 부종',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '반상출혈',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '괴사',
#   '비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '복부 통증'],
#  ['비브리오 패혈증(Vibrio vulnificus Septicemia)',
#   '물집',
#   '기운없음',
#   '오한',
#   '열',
#   '저혈압',
#   '설사',
#   '환부 부종',
#   '반상출혈',
#   '괴사',
#   '복부 통증'],
#  ['사마귀(Wart)', '검은 점', '사마귀(Wart)', '결절', '사마귀(Wart)', '사마귀 위 털이 많음'],
#  ['사마귀(Wart)', '검은 점', '결절', '사마귀 위 털이 많음'],
#  ['사면발이증(Pediculosis pubis)', '비정상적 질 분비물', '사면발이증(Pediculosis pubis)', '소양감'],
#  ['사면발이증(Pediculosis pubis)', '비정상적 질 분비물', '소양감'],
#  ['사타구니 백선(Tinea cruris)',
#   '색소 침착',
#   '사타구니 백선(Tinea cruris)',
#   '적색의 각질화된 피부',
#   '사타구니 백선(Tinea cruris)',
#   '소양감'],
#  ['사타구니 백선(Tinea cruris)', '색소 침착', '적색의 각질화된 피부', '소양감'],
#  ['상기도 감염(Upper respiratory infections)',
#   '열',
#   '상기도 감염(Upper respiratory infections)',
#   '기침',
#   '상기도 감염(Upper respiratory infections)',
#   '피로감',
#   '상기도 감염(Upper respiratory infections)',
#   '콧물',
#   '상기도 감염(Upper respiratory infections)',
#   '두통',
#   '상기도 감염(Upper respiratory infections)',
#   '코막힘',
#   '상기도 감염(Upper respiratory infections)',
#   '재채기',
#   '상기도 감염(Upper respiratory infections)',
#   '목의 통증'],
#  ['상기도 감염(Upper respiratory infections)',
#   '열',
#   '기침',
#   '피로감',
#   '콧물',
#   '두통',
#   '코막힘',
#   '재채기',
#   '목의 통증'],
#  ['샅(서혜)육아종(Granuloma inguinale)',
#   '물집',
#   '샅(서혜)육아종(Granuloma inguinale)',
#   '발진',
#   '샅(서혜)육아종(Granuloma inguinale)',
#   '환부의 분비물',
#   '샅(서혜)육아종(Granuloma inguinale)',
#   '생식기 궤양'],
#  ['샅(서혜)육아종(Granuloma inguinale)', '물집', '발진', '환부의 분비물', '생식기 궤양'],
#  ['샤가스병(Chagas disease)',
#   '열',
#   '샤가스병(Chagas disease)',
#   '눈 주변 부종',
#   '샤가스병(Chagas disease)',
#   '부정맥'],
#  ['샤가스병(Chagas disease)', '열', '눈 주변 부종', '부정맥'],
#  ['선모충증(Trichinellosis)',
#   '호흡곤란',
#   '선모충증(Trichinellosis)',
#   '설사',
#   '선모충증(Trichinellosis)',
#   '근육통',
#   '선모충증(Trichinellosis)',
#   '구토',
#   '선모충증(Trichinellosis)',
#   '복부 통증',
#   '선모충증(Trichinellosis)',
#   '무증상',
#   '선모충증(Trichinellosis)',
#   '말초 신경장애',
#   '선모충증(Trichinellosis)',
#   '열'],
#  ['선모충증(Trichinellosis)',
#   '호흡곤란',
#   '설사',
#   '근육통',
#   '구토',
#   '복부 통증',
#   '무증상',
#   '말초 신경장애',
#   '열'],
#  ['성병(Sexually transmitted disease)',
#   '소양감',
#   '성병(Sexually transmitted disease)',
#   '환부의 분비물',
#   '성병(Sexually transmitted disease)',
#   '비정상적 질 분비물'],
#  ['성병(Sexually transmitted disease)', '소양감', '환부의 분비물', '비정상적 질 분비물'],
#  ['성홍열(Scarlet fever)',
#   '딸기혀',
#   '성홍열(Scarlet fever)',
#   '식욕부진',
#   '성홍열(Scarlet fever)',
#   '편도선 비대',
#   '성홍열(Scarlet fever)',
#   '열',
#   '성홍열(Scarlet fever)',
#   '구토',
#   '성홍열(Scarlet fever)',
#   '발진'],
#  ['성홍열(Scarlet fever)', '딸기혀', '식욕부진', '편도선 비대', '열', '구토', '발진'],
#  ['세균성 이질(Shigellosis)',
#   '구토',
#   '세균성 이질(Shigellosis)',
#   '설사',
#   '세균성 이질(Shigellosis)',
#   '오심',
#   '세균성 이질(Shigellosis)',
#   '복부 통증',
#   '세균성 이질(Shigellosis)',
#   '열'],
#  ['세균성 이질(Shigellosis)', '구토', '설사', '오심', '복부 통증', '열'],
#  ['소아마비(Polio)', '열', '소아마비(Polio)', '무균성 뇌막염', '소아마비(Polio)', '이완성 마비'],
#  ['소아마비(Polio)', '열', '무균성 뇌막염', '이완성 마비'],
#  ['속립성 결핵(Miliary tuberculosis)',
#   '열',
#   '속립성 결핵(Miliary tuberculosis)',
#   '가래',
#   '속립성 결핵(Miliary tuberculosis)',
#   '객혈',
#   '속립성 결핵(Miliary tuberculosis)',
#   '체중감소',
#   '속립성 결핵(Miliary tuberculosis)',
#   '식욕부진',
#   '속립성 결핵(Miliary tuberculosis)',
#   '기침'],
#  ['속립성 결핵(Miliary tuberculosis)', '열', '가래', '객혈', '체중감소', '식욕부진', '기침'],
#  ['수두(Varicella (chickenpox))',
#   '열',
#   '수두(Varicella (chickenpox))',
#   '두통',
#   '수두(Varicella (chickenpox))',
#   '발한',
#   '수두(Varicella (chickenpox))',
#   '물집',
#   '수두(Varicella (chickenpox))',
#   '근육통',
#   '수두(Varicella (chickenpox))',
#   '식욕부진',
#   '수두(Varicella (chickenpox))',
#   '피부소양감',
#   '수두(Varicella (chickenpox))',
#   '발진'],
#  ['수두(Varicella (chickenpox))',
#   '열',
#   '두통',
#   '발한',
#   '물집',
#   '근육통',
#   '식욕부진',
#   '피부소양감',
#   '발진'],
#  ['수족구병(Hand, foot and mouth disease)',
#   '발진',
#   '수족구병(Hand, foot and mouth disease)',
#   '두통',
#   '수족구병(Hand, foot and mouth disease)',
#   '환부 통증',
#   '수족구병(Hand, foot and mouth disease)',
#   '열',
#   '수족구병(Hand, foot and mouth disease)',
#   '물집',
#   '수족구병(Hand, foot and mouth disease)',
#   '피부소양감'],
#  ['수족구병(Hand, foot and mouth disease)',
#   '발진',
#   '두통',
#   '환부 통증',
#   '열',
#   '물집',
#   '피부소양감'],
#  ['슈도모나스 감염(Pseudomonas infection)',
#   '발진',
#   '슈도모나스 감염(Pseudomonas infection)',
#   '열',
#   '슈도모나스 감염(Pseudomonas infection)',
#   '환부 통증',
#   '슈도모나스 감염(Pseudomonas infection)',
#   '피부염증'],
#  ['슈도모나스 감염(Pseudomonas infection)', '발진', '열', '환부 통증', '피부염증'],
#  ['스파르가눔증(Sparganosis)',
#   '뇌전증 발작',
#   '스파르가눔증(Sparganosis)',
#   '환부 통증',
#   '스파르가눔증(Sparganosis)',
#   '피부염증'],
#  ['스파르가눔증(Sparganosis)', '뇌전증 발작', '환부 통증', '피부염증'],
#  ['신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '무호흡',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '설사',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '서맥',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '혈변',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '저체온',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '복부팽만감',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '기민상태',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '신경과민',
#   '신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '구토'],
#  ['신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)',
#   '무호흡',
#   '설사',
#   '서맥',
#   '혈변',
#   '저체온',
#   '복부팽만감',
#   '기민상태',
#   '신경과민',
#   '구토'],
#  ['신종 플루(Novel swine-origin influenza A(H1N1))',
#   '설사',
#   '신종 플루(Novel swine-origin influenza A(H1N1))',
#   '목의 통증',
#   '신종 플루(Novel swine-origin influenza A(H1N1))',
#   '구토',
#   '신종 플루(Novel swine-origin influenza A(H1N1))',
#   '오한',
#   '신종 플루(Novel swine-origin influenza A(H1N1))',
#   '두통',
#   '신종 플루(Novel swine-origin influenza A(H1N1))',
#   '근육통'],
#  ['신종 플루(Novel swine-origin influenza A(H1N1))',
#   '설사',
#   '목의 통증',
#   '구토',
#   '오한',
#   '두통',
#   '근육통'],
#  ['신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '단백뇨',
#   '신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '저혈압',
#   '신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '식욕부진',
#   '신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '복부 통증',
#   '신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '다뇨',
#   '신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '두통',
#   '신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '열',
#   '신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '요독증'],
#  ['신증후성 출혈열(Hemorrhagic fever with renal syndrome)',
#   '단백뇨',
#   '저혈압',
#   '식욕부진',
#   '복부 통증',
#   '다뇨',
#   '두통',
#   '열',
#   '요독증'],
#  ['심내막염(Endocarditis)',
#   '두통',
#   '심내막염(Endocarditis)',
#   '호흡곤란',
#   '심내막염(Endocarditis)',
#   '열',
#   '심내막염(Endocarditis)',
#   '오한',
#   '심내막염(Endocarditis)',
#   '식욕부진',
#   '심내막염(Endocarditis)',
#   '저혈압',
#   '심내막염(Endocarditis)',
#   '반점'],
#  ['심내막염(Endocarditis)', '두통', '호흡곤란', '열', '오한', '식욕부진', '저혈압', '반점'],
#  ['아메바성 이질(Amebic dysentery)',
#   '잔변감',
#   '아메바성 이질(Amebic dysentery)',
#   '복부 통증',
#   '아메바성 이질(Amebic dysentery)',
#   '설사',
#   '아메바성 이질(Amebic dysentery)',
#   '혈변'],
#  ['아메바성 이질(Amebic dysentery)', '잔변감', '복부 통증', '설사', '혈변'],
#  ['아스페르길루스증(Aspergillosis)',
#   '천명음',
#   '아스페르길루스증(Aspergillosis)',
#   '오한',
#   '아스페르길루스증(Aspergillosis)',
#   '객혈',
#   '아스페르길루스증(Aspergillosis)',
#   '호흡곤란',
#   '아스페르길루스증(Aspergillosis)',
#   '열'],
#  ['아스페르길루스증(Aspergillosis)', '천명음', '오한', '객혈', '호흡곤란', '열'],
#  ['야토병(Tularemia)',
#   '오한',
#   '야토병(Tularemia)',
#   '열',
#   '야토병(Tularemia)',
#   '기침',
#   '야토병(Tularemia)',
#   '근육통',
#   '야토병(Tularemia)',
#   '권태감',
#   '야토병(Tularemia)',
#   '두통'],
#  ['야토병(Tularemia)', '오한', '열', '기침', '근육통', '권태감', '두통'],
#  ['에볼라 출혈열(Ebola hemorrhagic fever)',
#   '눈의 충혈',
#   '에볼라 출혈열(Ebola hemorrhagic fever)',
#   '열',
#   '에볼라 출혈열(Ebola hemorrhagic fever)',
#   '피로감',
#   '에볼라 출혈열(Ebola hemorrhagic fever)',
#   '가슴 통증',
#   '에볼라 출혈열(Ebola hemorrhagic fever)',
#   '발진',
#   '에볼라 출혈열(Ebola hemorrhagic fever)',
#   '점상 출혈',
#   '에볼라 출혈열(Ebola hemorrhagic fever)',
#   '근육통'],
#  ['에볼라 출혈열(Ebola hemorrhagic fever)',
#   '눈의 충혈',
#   '열',
#   '피로감',
#   '가슴 통증',
#   '발진',
#   '점상 출혈',
#   '근육통'],
#  ['옻 중독(Poison ivy dermatitis)',
#   '피부소양감',
#   '옻 중독(Poison ivy dermatitis)',
#   '오심',
#   '옻 중독(Poison ivy dermatitis)',
#   '구토',
#   '옻 중독(Poison ivy dermatitis)',
#   '장액성 분비물',
#   '옻 중독(Poison ivy dermatitis)',
#   '발진',
#   '옻 중독(Poison ivy dermatitis)',
#   '물집',
#   '옻 중독(Poison ivy dermatitis)',
#   '어지러움'],
#  ['옻 중독(Poison ivy dermatitis)',
#   '피부소양감',
#   '오심',
#   '구토',
#   '장액성 분비물',
#   '발진',
#   '물집',
#   '어지러움'],
#  ['요근 농양(Psoas abscess)',
#   '체중감소',
#   '요근 농양(Psoas abscess)',
#   '식욕부진',
#   '요근 농양(Psoas abscess)',
#   '덩어리가 만져짐',
#   '요근 농양(Psoas abscess)',
#   '골반 통증',
#   '요근 농양(Psoas abscess)',
#   '보행이상',
#   '요근 농양(Psoas abscess)',
#   '열',
#   '요근 농양(Psoas abscess)',
#   '요통',
#   '요근 농양(Psoas abscess)',
#   '기운없음'],
#  ['요근 농양(Psoas abscess)',
#   '체중감소',
#   '식욕부진',
#   '덩어리가 만져짐',
#   '골반 통증',
#   '보행이상',
#   '열',
#   '요통',
#   '기운없음'],
#  ['요충증(Enterobiasis)', '대변에 벌레 관찰됨', '요충증(Enterobiasis)', '소양감'],
#  ['요충증(Enterobiasis)', '대변에 벌레 관찰됨', '소양감'],
#  ['용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '멍',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '빈혈',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '황달',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '혈뇨',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '신부전',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '전신 부종',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '간비대',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '복수',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '구토',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '열',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '복부 통증',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '자반증',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '설사',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '고혈압',
#   '용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '혈변'],
#  ['용혈성 요독 증후군(Hemolytic Uremic Syndrome)',
#   '멍',
#   '빈혈',
#   '황달',
#   '혈뇨',
#   '신부전',
#   '전신 부종',
#   '간비대',
#   '복수',
#   '구토',
#   '열',
#   '복부 통증',
#   '자반증',
#   '설사',
#   '고혈압',
#   '혈변'],
#  ['원인을 알 수 없는 열(Fever of unknown origin)',
#   '열',
#   '원인을 알 수 없는 열(Fever of unknown origin)',
#   '구토',
#   '원인을 알 수 없는 열(Fever of unknown origin)',
#   '오심',
#   '원인을 알 수 없는 열(Fever of unknown origin)',
#   '발진',
#   '원인을 알 수 없는 열(Fever of unknown origin)',
#   '오한',
#   '원인을 알 수 없는 열(Fever of unknown origin)',
#   '근육통'],
#  ['원인을 알 수 없는 열(Fever of unknown origin)', '열', '구토', '오심', '발진', '오한', '근육통'],
#  ['원충성 질환(PROTOZOAL DISEASES)',
#   '설사',
#   '원충성 질환(PROTOZOAL DISEASES)',
#   '복부 통증',
#   '원충성 질환(PROTOZOAL DISEASES)',
#   '발진',
#   '원충성 질환(PROTOZOAL DISEASES)',
#   '두통',
#   '원충성 질환(PROTOZOAL DISEASES)',
#   '낮 시간대의 졸음',
#   '원충성 질환(PROTOZOAL DISEASES)',
#   '림프 부종'],
#  ['원충성 질환(PROTOZOAL DISEASES)',
#   '설사',
#   '복부 통증',
#   '발진',
#   '두통',
#   '낮 시간대의 졸음',
#   '림프 부종'],
#  ['웨스트나일열(West Nile Fever)',
#   '발진',
#   '웨스트나일열(West Nile Fever)',
#   '두통',
#   '웨스트나일열(West Nile Fever)',
#   '권태감',
#   '웨스트나일열(West Nile Fever)',
#   '근육통',
#   '웨스트나일열(West Nile Fever)',
#   '열'],
#  ['웨스트나일열(West Nile Fever)', '발진', '두통', '권태감', '근육통', '열'],
#  ['위장관 결핵(Gastrointestinal tuberculosis)',
#   '기운없음',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '변비',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '악취가 나는 설사',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '발한',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '복부팽만감',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '식욕부진',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '혈변',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '피로감',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '열',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '복부 통증',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '오심',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '설사',
#   '위장관 결핵(Gastrointestinal tuberculosis)',
#   '체중감소'],
#  ['위장관 결핵(Gastrointestinal tuberculosis)',
#   '기운없음',
#   '변비',
#   '악취가 나는 설사',
#   '발한',
#   '복부팽만감',
#   '식욕부진',
#   '혈변',
#   '피로감',
#   '열',
#   '복부 통증',
#   '오심',
#   '설사',
#   '체중감소'],
#  ['유행성 이하선염(Mumps)',
#   '열',
#   '유행성 이하선염(Mumps)',
#   '근육통',
#   '유행성 이하선염(Mumps)',
#   '귀의 통증',
#   '유행성 이하선염(Mumps)',
#   '두통',
#   '유행성 이하선염(Mumps)',
#   '목 주변 부종'],
#  ['유행성 이하선염(Mumps)', '열', '근육통', '귀의 통증', '두통', '목 주변 부종'],
#  ['인유두종 바이러스 감염증(Human papiloma virus infection)',
#   '결절',
#   '인유두종 바이러스 감염증(Human papiloma virus infection)',
#   '무증상'],
#  ['인유두종 바이러스 감염증(Human papiloma virus infection)', '결절', '무증상'],
#  ['인플루엔자(Influenza)',
#   '두통',
#   '인플루엔자(Influenza)',
#   '구토',
#   '인플루엔자(Influenza)',
#   '목의 통증',
#   '인플루엔자(Influenza)',
#   '열',
#   '인플루엔자(Influenza)',
#   '오한',
#   '인플루엔자(Influenza)',
#   '근육통',
#   '인플루엔자(Influenza)',
#   '설사'],
#  ['인플루엔자(Influenza)', '두통', '구토', '목의 통증', '열', '오한', '근육통', '설사'],
#  ['일본 뇌염(Japanese encephalitis)',
#   '감각 이상',
#   '일본 뇌염(Japanese encephalitis)',
#   '열',
#   '일본 뇌염(Japanese encephalitis)',
#   '무증상',
#   '일본 뇌염(Japanese encephalitis)',
#   '두통',
#   '일본 뇌염(Japanese encephalitis)',
#   '의식 변화',
#   '일본 뇌염(Japanese encephalitis)',
#   '혼수',
#   '일본 뇌염(Japanese encephalitis)',
#   '구토',
#   '일본 뇌염(Japanese encephalitis)',
#   '경련'],
#  ['일본 뇌염(Japanese encephalitis)',
#   '감각 이상',
#   '열',
#   '무증상',
#   '두통',
#   '의식 변화',
#   '혼수',
#   '구토',
#   '경련'],
#  ['임파선염(Lymphadenitis)',
#   '고름',
#   '임파선염(Lymphadenitis)',
#   '열감',
#   '임파선염(Lymphadenitis)',
#   '열',
#   '임파선염(Lymphadenitis)',
#   '환부 부종',
#   '임파선염(Lymphadenitis)',
#   '환부 통증',
#   '임파선염(Lymphadenitis)',
#   '피부궤양',
#   '임파선염(Lymphadenitis)',
#   '발적'],
#  ['임파선염(Lymphadenitis)', '고름', '열감', '열', '환부 부종', '환부 통증', '피부궤양', '발적'],
#  ['자궁경부염(Cervicitis)',
#   '복부 통증',
#   '자궁경부염(Cervicitis)',
#   '골반 통증',
#   '자궁경부염(Cervicitis)',
#   '비정상적 질 분비물',
#   '자궁경부염(Cervicitis)',
#   '비정상적 질출혈',
#   '자궁경부염(Cervicitis)',
#   '생식기 부종',
#   '자궁경부염(Cervicitis)',
#   '잔뇨감',
#   '자궁경부염(Cervicitis)',
#   '생식기 통증'],
#  ['자궁경부염(Cervicitis)',
#   '복부 통증',
#   '골반 통증',
#   '비정상적 질 분비물',
#   '비정상적 질출혈',
#   '생식기 부종',
#   '잔뇨감',
#   '생식기 통증'],
#  ['장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '요독증',
#   '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '빈혈',
#   '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '혈변',
#   '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '혈소판감소',
#   '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '복부경련',
#   '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '복부 통증',
#   '장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '설사'],
#  ['장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)',
#   '요독증',
#   '빈혈',
#   '혈변',
#   '혈소판감소',
#   '복부경련',
#   '복부 통증',
#   '설사'],
#  ['장티푸스(typhoid fever)',
#   '오한',
#   '장티푸스(typhoid fever)',
#   '변비',
#   '장티푸스(typhoid fever)',
#   '반점',
#   '장티푸스(typhoid fever)',
#   '두통',
#   '장티푸스(typhoid fever)',
#   '설사',
#   '장티푸스(typhoid fever)',
#   '열'],
#  ['장티푸스(typhoid fever)', '오한', '변비', '반점', '두통', '설사', '열'],
#  ['조갑주위염(Paronychia)',
#   '고름',
#   '조갑주위염(Paronychia)',
#   '압통',
#   '조갑주위염(Paronychia)',
#   '손,발톱이 두꺼워짐',
#   '조갑주위염(Paronychia)',
#   '손,발톱이 갈라짐',
#   '조갑주위염(Paronychia)',
#   '발적'],
#  ['조갑주위염(Paronychia)', '고름', '압통', '손,발톱이 두꺼워짐', '손,발톱이 갈라짐', '발적'],
#  ['조류 인플루엔자(AI) 인체감염증(Avian Influenza Human Infection)',
#   '근육통',
#   '조류 인플루엔자(AI) 인체감염증(Avian Influenza Human Infection)',
#   '열',
#   '조류 인플루엔자(AI) 인체감염증(Avian Influenza Human Infection)',
#   '오한',
#   '조류 인플루엔자(AI) 인체감염증(Avian Influenza Human Infection)',
#   '기침',
#   '조류 인플루엔자(AI) 인체감염증(Avian Influenza Human Infection)',
#   '목의 통증'],
#  ['조류 인플루엔자(AI) 인체감염증(Avian Influenza Human Infection)',
#   '근육통',
#   '열',
#   '오한',
#   '기침',
#   '목의 통증'],
#  ['중동 호흡기 증후군(MERS)(Middle East Respiratory Syndrome)',
#   '열',
#   '중동 호흡기 증후군(MERS)(Middle East Respiratory Syndrome)',
#   '급성 신부전',
#   '중동 호흡기 증후군(MERS)(Middle East Respiratory Syndrome)',
#   '호흡곤란',
#   '중동 호흡기 증후군(MERS)(Middle East Respiratory Syndrome)',
#   '기침'],
#  ['중동 호흡기 증후군(MERS)(Middle East Respiratory Syndrome)',
#   '열',
#   '급성 신부전',
#   '호흡곤란',
#   '기침'],
#  ['중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '기침',
#   '중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '근육통',
#   '중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '열',
#   '중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '권태감',
#   '중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '오한',
#   '중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '호흡곤란',
#   '중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '두통'],
#  ['중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)',
#   '기침',
#   '근육통',
#   '열',
#   '권태감',
#   '오한',
#   '호흡곤란',
#   '두통'],
#  ['중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '열',
#   '중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '복부 통증',
#   '중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '설사',
#   '중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '두통',
#   '중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '혈소판감소',
#   '중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '식욕부진',
#   '중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '구토',
#   '중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '피로감'],
#  ['중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))',
#   '열',
#   '복부 통증',
#   '설사',
#   '두통',
#   '혈소판감소',
#   '식욕부진',
#   '구토',
#   '피로감'],
#  ['증상이 없는 HIV 감염(HIV infection, asymptomatic)', '무증상'],
#  ['증상이 없는 HIV 감염(HIV infection, asymptomatic)', '무증상'],
#  ['지역사회성 폐렴(Community acquired pneumonia)',
#   '가래',
#   '지역사회성 폐렴(Community acquired pneumonia)',
#   '기침',
#   '지역사회성 폐렴(Community acquired pneumonia)',
#   '감기 증상',
#   '지역사회성 폐렴(Community acquired pneumonia)',
#   '가슴 통증',
#   '지역사회성 폐렴(Community acquired pneumonia)',
#   '호흡곤란'],
#  ['지역사회성 폐렴(Community acquired pneumonia)',
#   '가래',
#   '기침',
#   '감기 증상',
#   '가슴 통증',
#   '호흡곤란'],
#  ['지카 바이러스 감염증(Zikavirus Infection)',
#   '열',
#   '지카 바이러스 감염증(Zikavirus Infection)',
#   '발진',
#   '지카 바이러스 감염증(Zikavirus Infection)',
#   '관절통',
#   '지카 바이러스 감염증(Zikavirus Infection)',
#   '눈의 충혈'],
#  ['지카 바이러스 감염증(Zikavirus Infection)', '열', '발진', '관절통', '눈의 충혈'],
#  ['첨형 콘딜로마(Condyloma accuminatum)',
#   '회음부의 작은 돌기',
#   '첨형 콘딜로마(Condyloma accuminatum)',
#   '소양감',
#   '첨형 콘딜로마(Condyloma accuminatum)',
#   '생식기 출혈'],
#  ['첨형 콘딜로마(Condyloma accuminatum)', '회음부의 작은 돌기', '소양감', '생식기 출혈'],
#  ['치쿤구니야열(Chikungunya Fever)',
#   '오한',
#   '치쿤구니야열(Chikungunya Fever)',
#   '권태감',
#   '치쿤구니야열(Chikungunya Fever)',
#   '발진',
#   '치쿤구니야열(Chikungunya Fever)',
#   '근육통',
#   '치쿤구니야열(Chikungunya Fever)',
#   '열'],
#  ['치쿤구니야열(Chikungunya Fever)', '오한', '권태감', '발진', '근육통', '열'],
#  ['칸디다성 구내염(Candidal stomatitis)',
#   '하얀 반점',
#   '칸디다성 구내염(Candidal stomatitis)',
#   '환부 통증',
#   '칸디다성 구내염(Candidal stomatitis)',
#   '열',
#   '칸디다성 구내염(Candidal stomatitis)',
#   '식욕부진',
#   '칸디다성 구내염(Candidal stomatitis)',
#   '구취'],
#  ['칸디다성 구내염(Candidal stomatitis)', '하얀 반점', '환부 통증', '열', '식욕부진', '구취'],
#  ['캄필로박터 감염증(Campylobacteriosis)',
#   '열',
#   '캄필로박터 감염증(Campylobacteriosis)',
#   '복부 통증',
#   '캄필로박터 감염증(Campylobacteriosis)',
#   '두통',
#   '캄필로박터 감염증(Campylobacteriosis)',
#   '혈변',
#   '캄필로박터 감염증(Campylobacteriosis)',
#   '근육통',
#   '캄필로박터 감염증(Campylobacteriosis)',
#   '설사'],
#  ['캄필로박터 감염증(Campylobacteriosis)', '열', '복부 통증', '두통', '혈변', '근육통', '설사'],
#  ['코로나-19(COVID-19)',
#   '가래',
#   '코로나-19(COVID-19)',
#   '열',
#   '코로나-19(COVID-19)',
#   '두통',
#   '코로나-19(COVID-19)',
#   '목의 통증',
#   '코로나-19(COVID-19)',
#   '근육통',
#   '코로나-19(COVID-19)',
#   '피로감',
#   '코로나-19(COVID-19)',
#   '호흡곤란',
#   '코로나-19(COVID-19)',
#   '기침'],
#  ['코로나-19(COVID-19)', '가래', '열', '두통', '목의 통증', '근육통', '피로감', '호흡곤란', '기침'],
#  ['콜레라(Cholera)',
#   '오심',
#   '콜레라(Cholera)',
#   '열',
#   '콜레라(Cholera)',
#   '탈수',
#   '콜레라(Cholera)',
#   '구토',
#   '콜레라(Cholera)',
#   '설사'],
#  ['콜레라(Cholera)', '오심', '열', '탈수', '구토', '설사'],
#  ['큐열(Q Fever)',
#   '기침',
#   '큐열(Q Fever)',
#   '열',
#   '큐열(Q Fever)',
#   '발진',
#   '큐열(Q Fever)',
#   '두통',
#   '큐열(Q Fever)',
#   '간비대',
#   '큐열(Q Fever)',
#   '목의 통증',
#   '큐열(Q Fever)',
#   '구토',
#   '큐열(Q Fever)',
#   '권태감',
#   '큐열(Q Fever)',
#   '오한',
#   '큐열(Q Fever)',
#   '근육통',
#   '큐열(Q Fever)',
#   '설사'],
#  ['큐열(Q Fever)',
#   '기침',
#   '열',
#   '발진',
#   '두통',
#   '간비대',
#   '목의 통증',
#   '구토',
#   '권태감',
#   '오한',
#   '근육통',
#   '설사'],
#  ['크로이츠펠트-야콥병(Creutzfeldt-Jakob disease)',
#   '운동장애',
#   '크로이츠펠트-야콥병(Creutzfeldt-Jakob disease)',
#   '근육경련',
#   '크로이츠펠트-야콥병(Creutzfeldt-Jakob disease)',
#   '건망증',
#   '크로이츠펠트-야콥병(Creutzfeldt-Jakob disease)',
#   '인지장애',
#   '크로이츠펠트-야콥병(Creutzfeldt-Jakob disease)',
#   '방향감각 상실'],
#  ['크로이츠펠트-야콥병(Creutzfeldt-Jakob disease)',
#   '운동장애',
#   '근육경련',
#   '건망증',
#   '인지장애',
#   '방향감각 상실'],
#  ['탄저병(Anthrax)',
#   '복부 통증',
#   '탄저병(Anthrax)',
#   '감기 증상',
#   '탄저병(Anthrax)',
#   '물집',
#   '탄저병(Anthrax)',
#   '피부소양감',
#   '탄저병(Anthrax)',
#   '열'],
#  ['탄저병(Anthrax)', '복부 통증', '감기 증상', '물집', '피부소양감', '열'],
#  ['털진드기병(Scrub typhus)',
#   '딱지',
#   '털진드기병(Scrub typhus)',
#   '두통',
#   '털진드기병(Scrub typhus)',
#   '경부 림프절병증',
#   '털진드기병(Scrub typhus)',
#   '열',
#   '털진드기병(Scrub typhus)',
#   '온몸이 떨림',
#   '털진드기병(Scrub typhus)',
#   '오한',
#   '털진드기병(Scrub typhus)',
#   '물집',
#   '털진드기병(Scrub typhus)',
#   '발진'],
#  ['털진드기병(Scrub typhus)',
#   '딱지',
#   '두통',
#   '경부 림프절병증',
#   '열',
#   '온몸이 떨림',
#   '오한',
#   '물집',
#   '발진'],
#  ['톡소플라즈마증(Toxoplasmosis)',
#   '눈의 통증',
#   '톡소플라즈마증(Toxoplasmosis)',
#   '기침',
#   '톡소플라즈마증(Toxoplasmosis)',
#   '객혈',
#   '톡소플라즈마증(Toxoplasmosis)',
#   '눈부심',
#   '톡소플라즈마증(Toxoplasmosis)',
#   '호흡곤란'],
#  ['톡소플라즈마증(Toxoplasmosis)', '눈의 통증', '기침', '객혈', '눈부심', '호흡곤란'],
#  ['파라인플루엔자 감염증(Parainfluenza infection)',
#   '식욕부진',
#   '파라인플루엔자 감염증(Parainfluenza infection)',
#   '편도선 비대',
#   '파라인플루엔자 감염증(Parainfluenza infection)',
#   '기침',
#   '파라인플루엔자 감염증(Parainfluenza infection)',
#   '가래',
#   '파라인플루엔자 감염증(Parainfluenza infection)',
#   '콧물',
#   '파라인플루엔자 감염증(Parainfluenza infection)',
#   '열',
#   '파라인플루엔자 감염증(Parainfluenza infection)',
#   '고막 충혈',
#   '파라인플루엔자 감염증(Parainfluenza infection)',
#   '구토'],
#  ['파라인플루엔자 감염증(Parainfluenza infection)',
#   '식욕부진',
#   '편도선 비대',
#   '기침',
#   '가래',
#   '콧물',
#   '열',
#   '고막 충혈',
#   '구토'],
#  ['파라티푸스(Paratyphoid fever)',
#   '발진',
#   '파라티푸스(Paratyphoid fever)',
#   '두통',
#   '파라티푸스(Paratyphoid fever)',
#   '설사',
#   '파라티푸스(Paratyphoid fever)',
#   '복부 통증'],
#  ['파라티푸스(Paratyphoid fever)', '발진', '두통', '설사', '복부 통증'],
#  ['파상풍(Tetanus)',
#   '오심',
#   '파상풍(Tetanus)',
#   '구토',
#   '파상풍(Tetanus)',
#   '두통',
#   '파상풍(Tetanus)',
#   '근육강직',
#   '파상풍(Tetanus)',
#   '호흡곤란',
#   '파상풍(Tetanus)',
#   '비웃는 듯한 표정',
#   '파상풍(Tetanus)',
#   '후궁반장',
#   '파상풍(Tetanus)',
#   '삼키기 곤란'],
#  ['파상풍(Tetanus)',
#   '오심',
#   '구토',
#   '두통',
#   '근육강직',
#   '호흡곤란',
#   '비웃는 듯한 표정',
#   '후궁반장',
#   '삼키기 곤란'],
#  ['패혈성 관절염(Septic arthtritis)',
#   '관절 운동성 감소',
#   '패혈성 관절염(Septic arthtritis)',
#   '환부 부종',
#   '패혈성 관절염(Septic arthtritis)',
#   '오한',
#   '패혈성 관절염(Septic arthtritis)',
#   '열감',
#   '패혈성 관절염(Septic arthtritis)',
#   '관절염',
#   '패혈성 관절염(Septic arthtritis)',
#   '열',
#   '패혈성 관절염(Septic arthtritis)',
#   '관절통'],
#  ['패혈성 관절염(Septic arthtritis)',
#   '관절 운동성 감소',
#   '환부 부종',
#   '오한',
#   '열감',
#   '관절염',
#   '열',
#   '관절통'],
#  ['패혈증(Sepsis)',
#   '빈맥',
#   '패혈증(Sepsis)',
#   '빈호흡',
#   '패혈증(Sepsis)',
#   '심부전',
#   '패혈증(Sepsis)',
#   '저혈압',
#   '패혈증(Sepsis)',
#   '열',
#   '패혈증(Sepsis)',
#   '의식 저하',
#   '패혈증(Sepsis)',
#   '소변량 감소',
#   '패혈증(Sepsis)',
#   '오한'],
#  ['패혈증(Sepsis)', '빈맥', '빈호흡', '심부전', '저혈압', '열', '의식 저하', '소변량 감소', '오한'],
#  ['폐결핵(Pulmonary tuberculosis)',
#   '열',
#   '폐결핵(Pulmonary tuberculosis)',
#   '가래',
#   '폐결핵(Pulmonary tuberculosis)',
#   '객혈',
#   '폐결핵(Pulmonary tuberculosis)',
#   '체중감소',
#   '폐결핵(Pulmonary tuberculosis)',
#   '기침'],
#  ['폐결핵(Pulmonary tuberculosis)', '열', '가래', '객혈', '체중감소', '기침'],
#  ['폐색성 혈전 혈관염 (Thromboangiitis obliterans)',
#   '말초 통증',
#   '폐색성 혈전 혈관염 (Thromboangiitis obliterans)',
#   '말초의 허혈',
#   '폐색성 혈전 혈관염 (Thromboangiitis obliterans)',
#   '저림'],
#  ['폐색성 혈전 혈관염 (Thromboangiitis obliterans)', '말초 통증', '말초의 허혈', '저림'],
#  ['포도상구균 감염(Staphylococcus aureus infection)',
#   '발진',
#   '포도상구균 감염(Staphylococcus aureus infection)',
#   '환부 통증',
#   '포도상구균 감염(Staphylococcus aureus infection)',
#   '열'],
#  ['포도상구균 감염(Staphylococcus aureus infection)', '발진', '환부 통증', '열'],
#  ['풍진(Rubella(German measles))',
#   '발진',
#   '풍진(Rubella(German measles))',
#   '두통',
#   '풍진(Rubella(German measles))',
#   '권태감',
#   '풍진(Rubella(German measles))',
#   '림프 부종',
#   '풍진(Rubella(German measles))',
#   '열',
#   '풍진(Rubella(German measles))',
#   '눈의 충혈'],
#  ['풍진(Rubella(German measles))', '발진', '두통', '권태감', '림프 부종', '열', '눈의 충혈'],
#  ['한센병(Leprosy)',
#   '안구혼탁',
#   '한센병(Leprosy)',
#   '피부염증',
#   '한센병(Leprosy)',
#   '결절',
#   '한센병(Leprosy)',
#   '발진',
#   '한센병(Leprosy)',
#   '눈물흘림'],
#  ['한센병(Leprosy)', '안구혼탁', '피부염증', '결절', '발진', '눈물흘림'],
#  ['헤르페스 바이러스 감염(Herpesviral infection)',
#   '물집',
#   '헤르페스 바이러스 감염(Herpesviral infection)',
#   '피부염증'],
#  ['헤르페스 바이러스 감염(Herpesviral infection)', '물집', '피부염증'],
#  ['호산구 증가증(Eosinophilia)',
#   '전신 부종',
#   '호산구 증가증(Eosinophilia)',
#   '피로감',
#   '호산구 증가증(Eosinophilia)',
#   '피부소양감',
#   '호산구 증가증(Eosinophilia)',
#   '기침',
#   '호산구 증가증(Eosinophilia)',
#   '열',
#   '호산구 증가증(Eosinophilia)',
#   '체중감소'],
#  ['호산구 증가증(Eosinophilia)', '전신 부종', '피로감', '피부소양감', '기침', '열', '체중감소'],
#  ['홍역(Measles)',
#   '열',
#   '홍역(Measles)',
#   '기침',
#   '홍역(Measles)',
#   '림프 부종',
#   '홍역(Measles)',
#   '식욕부진',
#   '홍역(Measles)',
#   '피부소양감',
#   '홍역(Measles)',
#   '콧물',
#   '홍역(Measles)',
#   '코플릭 반점'],
#  ['홍역(Measles)', '열', '기침', '림프 부종', '식욕부진', '피부소양감', '콧물', '코플릭 반점'],
#  ['황열(Yellow fever)',
#   '열',
#   '황열(Yellow fever)',
#   '복부 통증',
#   '황열(Yellow fever)',
#   '근육통',
#   '황열(Yellow fever)',
#   '서맥',
#   '황열(Yellow fever)',
#   '구토',
#   '황열(Yellow fever)',
#   '무증상',
#   '황열(Yellow fever)',
#   '황달'],
#  ['황열(Yellow fever)', '열', '복부 통증', '근육통', '서맥', '구토', '무증상', '황달'],
#  ['효모균증(Cryptococcosis)',
#   '열',
#   '효모균증(Cryptococcosis)',
#   '경부 강직',
#   '효모균증(Cryptococcosis)',
#   '피부궤양',
#   '효모균증(Cryptococcosis)',
#   '호흡곤란',
#   '효모균증(Cryptococcosis)',
#   '두통',
#   '효모균증(Cryptococcosis)',
#   '가슴 통증'],
#  ['효모균증(Cryptococcosis)', '열', '경부 강직', '피부궤양', '호흡곤란', '두통', '가슴 통증'],
#  ['후두개염(Epiglottitis)',
#   '사망',
#   '후두개염(Epiglottitis)',
#   '열',
#   '후두개염(Epiglottitis)',
#   '호흡곤란',
#   '후두개염(Epiglottitis)',
#   '목소리 변화',
#   '후두개염(Epiglottitis)',
#   '청색증'],
#  ['후두개염(Epiglottitis)', '사망', '열', '호흡곤란', '목소리 변화', '청색증'],
#  ['후천성 면역결핍증(Acquired immunodeficiency syndrome)',
#   '발진',
#   '후천성 면역결핍증(Acquired immunodeficiency syndrome)',
#   '악성종양발생',
#   '후천성 면역결핍증(Acquired immunodeficiency syndrome)',
#   '구토',
#   '후천성 면역결핍증(Acquired immunodeficiency syndrome)',
#   '림프 부종'],
#  ['후천성 면역결핍증(Acquired immunodeficiency syndrome)',
#   '발진',
#   '악성종양발생',
#   '구토',
#   '림프 부종'],
#  ['흑사병(Yersinia Pestis)',
#   '가슴 통증',
#   '흑사병(Yersinia Pestis)',
#   '점상 출혈',
#   '흑사병(Yersinia Pestis)',
#   '반점',
#   '흑사병(Yersinia Pestis)',
#   '객혈',
#   '흑사병(Yersinia Pestis)',
#   '기침',
#   '흑사병(Yersinia Pestis)',
#   '열',
#   '흑사병(Yersinia Pestis)',
#   '호흡곤란'],
#  ['흑사병(Yersinia Pestis)', '가슴 통증', '점상 출혈', '반점', '객혈', '기침', '열', '호흡곤란'],
#  ['히스토플라즈마증(Histoplasmosis)',
#   '가슴 통증',
#   '히스토플라즈마증(Histoplasmosis)',
#   '열',
#   '히스토플라즈마증(Histoplasmosis)',
#   '기침',
#   '히스토플라즈마증(Histoplasmosis)',
#   '오한',
#   '히스토플라즈마증(Histoplasmosis)',
#   '호흡곤란'],
#  ['히스토플라즈마증(Histoplasmosis)', '가슴 통증', '열', '기침', '오한', '호흡곤란'],
#  ['고혈압(Essential (primary) hypertension)',
#   '어지러움',
#   '고혈압(Essential (primary) hypertension)',
#   '두통',
#   '고혈압(Essential (primary) hypertension)',
#   '피부 긴장도 저하',
#   '고혈압(Essential (primary) hypertension)',
#   '가슴 두근거림'],
#  ['고혈압(Essential (primary) hypertension)',
#   '어지러움',
#   '두통',
#   '피부 긴장도 저하',
#   '가슴 두근거림'],
#  ['괴혈병(scurvy)',
#   '기운없음',
#   '괴혈병(scurvy)',
#   '출혈 경향성',
#   '괴혈병(scurvy)',
#   '뼈의 변형',
#   '괴혈병(scurvy)',
#   '식욕부진',
#   '괴혈병(scurvy)',
#   '권태감',
#   '괴혈병(scurvy)',
#   '철결핍성 빈혈'],
#  ['괴혈병(scurvy)', '기운없음', '출혈 경향성', '뼈의 변형', '식욕부진', '권태감', '철결핍성 빈혈'],
#  ['근감소증(Sarcopenia)',
#   '보행이상',
#   '근감소증(Sarcopenia)',
#   '근력 약화',
#   '근감소증(Sarcopenia)',
#   '하지의 근력약화',
#   '근감소증(Sarcopenia)',
#   '피로감'],
#  ['근감소증(Sarcopenia)', '보행이상', '근력 약화', '하지의 근력약화', '피로감'],
#  ['납 중독(Lead Poisoning)',
#   '복부 통증',
#   '납 중독(Lead Poisoning)',
#   '권태감',
#   '납 중독(Lead Poisoning)',
#   '식욕부진',
#   '납 중독(Lead Poisoning)',
#   '성격의변화',
#   '납 중독(Lead Poisoning)',
#   '구토',
#   '납 중독(Lead Poisoning)',
#   '빈혈',
#   '납 중독(Lead Poisoning)',
#   '두통',
#   '납 중독(Lead Poisoning)',
#   '불면증',
#   '납 중독(Lead Poisoning)',
#   '경련',
#   '납 중독(Lead Poisoning)',
#   '변비',
#   '납 중독(Lead Poisoning)',
#   '복부팽만감'],
#  ['납 중독(Lead Poisoning)',
#   '복부 통증',
#   '권태감',
#   '식욕부진',
#   '성격의변화',
#   '구토',
#   '빈혈',
#   '두통',
#   '불면증',
#   '경련',
#   '변비',
#   '복부팽만감'],
#  ['냉방병(Air-conditioningitis)',
#   '재채기',
#   '냉방병(Air-conditioningitis)',
#   '코막힘',
#   '냉방병(Air-conditioningitis)',
#   '소화불량',
#   '냉방병(Air-conditioningitis)',
#   '콧물',
#   '냉방병(Air-conditioningitis)',
#   '권태감',
#   '냉방병(Air-conditioningitis)',
#   '설사',
#   '냉방병(Air-conditioningitis)',
#   '복부 불편감'],
#  ['냉방병(Air-conditioningitis)',
#   '재채기',
#   '코막힘',
#   '소화불량',
#   '콧물',
#   '권태감',
#   '설사',
#   '복부 불편감'],
#  ['노쇠(Frailty)',
#   '식욕부진',
#   '노쇠(Frailty)',
#   '기억장애',
#   '노쇠(Frailty)',
#   '보행이상',
#   '노쇠(Frailty)',
#   '어지러움',
#   '노쇠(Frailty)',
#   '피로감',
#   '노쇠(Frailty)',
#   '체중감소',
#   '노쇠(Frailty)',
#   '하지의 근력약화',
#   '노쇠(Frailty)',
#   '근력 약화'],
#  ['노쇠(Frailty)',
#   '식욕부진',
#   '기억장애',
#   '보행이상',
#   '어지러움',
#   '피로감',
#   '체중감소',
#   '하지의 근력약화',
#   '근력 약화'],
#  ['노화(Senility)',
#   '눈가 및 이마 주름',
#   '노화(Senility)',
#   '골다공증',
#   '노화(Senility)',
#   '이마의 주름',
#   '노화(Senility)',
#   '코 옆과 입꼬리 주름'],
# ...
#   '접촉도착증',
#   '피학증',
#   '비정상적 성적 기호',
#   '소아기호증'],
#  ['성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '충동 조절 어려움',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '대인관계 어려움',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '감정 변화',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '우울',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '산만함',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '인내심이 부족함',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '대화에 불쑥 끼어듬',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '낮은 자존감',
#   '성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '건망증'],
#  ['성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)',
#   '충동 조절 어려움',
#   '대인관계 어려움',
#   '감정 변화',
#   '우울',
#   '산만함',
#   '인내심이 부족함',
#   '대화에 불쑥 끼어듬',
#   '낮은 자존감',
#   '건망증'],
#  ['소아청소년기 우울증(Depression in childhood and adolescence)',
#   '초조함',
#   '소아청소년기 우울증(Depression in childhood and adolescence)',
#   '권태감',
#   '소아청소년기 우울증(Depression in childhood and adolescence)',
#   '우울',
#   '소아청소년기 우울증(Depression in childhood and adolescence)',
#   '감정 변화',
#   '소아청소년기 우울증(Depression in childhood and adolescence)',
#   '수면장애'],
#  ['소아청소년기 우울증(Depression in childhood and adolescence)',
#   '초조함',
#   '권태감',
#   '우울',
#   '감정 변화',
#   '수면장애'],
#  ['수두증(Hydrocephalus)',
#   '축 늘어짐',
#   '수두증(Hydrocephalus)',
#   '수유 곤란',
#   '수두증(Hydrocephalus)',
#   '시력 감소',
#   '수두증(Hydrocephalus)',
#   '마비',
#   '수두증(Hydrocephalus)',
#   '두통',
#   '수두증(Hydrocephalus)',
#   '구토',
#   '수두증(Hydrocephalus)',
#   '기억장애',
#   '수두증(Hydrocephalus)',
#   '유두부종',
#   '수두증(Hydrocephalus)',
#   '눈운동신경마비'],
#  ['수두증(Hydrocephalus)',
#   '축 늘어짐',
#   '수유 곤란',
#   '시력 감소',
#   '마비',
#   '두통',
#   '구토',
#   '기억장애',
#   '유두부종',
#   '눈운동신경마비'],
#  ['수막종(Meningioma)',
#   '뇌전증 발작',
#   '수막종(Meningioma)',
#   '복시',
#   '수막종(Meningioma)',
#   '감정 변화',
#   '수막종(Meningioma)',
#   '두통',
#   '수막종(Meningioma)',
#   '언어장애',
#   '수막종(Meningioma)',
#   '운동장애',
#   '수막종(Meningioma)',
#   '시력 감소'],
#  ['수막종(Meningioma)', '뇌전증 발작', '복시', '감정 변화', '두통', '언어장애', '운동장애', '시력 감소'],
#  ['수면 무호흡증(Sleep apnea)',
#   '수면 무호흡',
#   '수면 무호흡증(Sleep apnea)',
#   '몽유병',
#   '수면 무호흡증(Sleep apnea)',
#   '불면증',
#   '수면 무호흡증(Sleep apnea)',
#   '발기부전',
#   '수면 무호흡증(Sleep apnea)',
#   '피부 긴장도 저하'],
#  ['수면 무호흡증(Sleep apnea)', '수면 무호흡', '몽유병', '불면증', '발기부전', '피부 긴장도 저하'],
#  ['수면 장애(Sleep Disorder)',
#   '수면 무호흡',
#   '수면 장애(Sleep Disorder)',
#   '수면 시작이 어려움',
#   '수면 장애(Sleep Disorder)',
#   '수면 중 이상한 행동',
#   '수면 장애(Sleep Disorder)',
#   '수면 주기의 변화',
#   '수면 장애(Sleep Disorder)',
#   '수면 유지가 어려움',
#   '수면 장애(Sleep Disorder)',
#   '낮 시간대의 졸음',
#   '수면 장애(Sleep Disorder)',
#   '입수면기의 환각',
#   '수면 장애(Sleep Disorder)',
#   '수면 마비',
#   '수면 장애(Sleep Disorder)',
#   '몽유병'],
#  ['수면 장애(Sleep Disorder)',
#   '수면 무호흡',
#   '수면 시작이 어려움',
#   '수면 중 이상한 행동',
#   '수면 주기의 변화',
#   '수면 유지가 어려움',
#   '낮 시간대의 졸음',
#   '입수면기의 환각',
#   '수면 마비',
#   '몽유병'],
#  ['수면보행증(Somnambulism)', '수면 중 보행', '수면보행증(Somnambulism)', '깨어나면 기억하지 못함'],
#  ['수면보행증(Somnambulism)', '수면 중 보행', '깨어나면 기억하지 못함'],
#  ['스터지 웨버 증후군(Sturge Weber Syndrome)',
#   '반점',
#   '스터지 웨버 증후군(Sturge Weber Syndrome)',
#   '뇌전증 발작',
#   '스터지 웨버 증후군(Sturge Weber Syndrome)',
#   '태아',
#   '스터지 웨버 증후군(Sturge Weber Syndrome)',
#   '신생아의 정신 장애',
#   '스터지 웨버 증후군(Sturge Weber Syndrome)',
#   '안구돌출'],
#  ['스터지 웨버 증후군(Sturge Weber Syndrome)',
#   '반점',
#   '뇌전증 발작',
#   '태아',
#   '신생아의 정신 장애',
#   '안구돌출'],
#  ['스핑고 지질증(Other sphingolipidosis)',
#   '경련',
#   '스핑고 지질증(Other sphingolipidosis)',
#   '실행증',
#   '스핑고 지질증(Other sphingolipidosis)',
#   '눈운동신경마비',
#   '스핑고 지질증(Other sphingolipidosis)',
#   '학습장애',
#   '스핑고 지질증(Other sphingolipidosis)',
#   '손',
#   '스핑고 지질증(Other sphingolipidosis)',
#   '발 감각 저하'],
#  ['스핑고 지질증(Other sphingolipidosis)',
#   '경련',
#   '실행증',
#   '눈운동신경마비',
#   '학습장애',
#   '손',
#   '발 감각 저하'],
#  ['신경근병증(Radiculopathy)',
#   '방사통',
#   '신경근병증(Radiculopathy)',
#   '요통',
#   '신경근병증(Radiculopathy)',
#   '감각 이상',
#   '신경근병증(Radiculopathy)',
#   '목의 통증',
#   '신경근병증(Radiculopathy)',
#   '근력 약화'],
#  ['신경근병증(Radiculopathy)', '방사통', '요통', '감각 이상', '목의 통증', '근력 약화'],
#  ['신경섬유종(Neurofibromatosis)',
#   '시력 감소',
#   '신경섬유종(Neurofibromatosis)',
#   '척추 측만',
#   '신경섬유종(Neurofibromatosis)',
#   '갈색 피부 반점'],
#  ['신경섬유종(Neurofibromatosis)', '시력 감소', '척추 측만', '갈색 피부 반점'],
#  ['신경성 식욕부진증(Anorexia nervosa)',
#   '무월경',
#   '신경성 식욕부진증(Anorexia nervosa)',
#   '저혈압',
#   '신경성 식욕부진증(Anorexia nervosa)',
#   '이상행동',
#   '신경성 식욕부진증(Anorexia nervosa)',
#   '체중감소'],
#  ['신경성 식욕부진증(Anorexia nervosa)', '무월경', '저혈압', '이상행동', '체중감소'],
#  ['신경성 폭식증(Bulimia nervosa)',
#   '체중증가',
#   '신경성 폭식증(Bulimia nervosa)',
#   '폭식',
#   '신경성 폭식증(Bulimia nervosa)',
#   '복부 통증',
#   '신경성 폭식증(Bulimia nervosa)',
#   '구토'],
#  ['신경성 폭식증(Bulimia nervosa)', '체중증가', '폭식', '복부 통증', '구토'],
#  ['신경절 신경종(Ganglioneuroma)',
#   '발한',
#   '신경절 신경종(Ganglioneuroma)',
#   '호흡곤란',
#   '신경절 신경종(Ganglioneuroma)',
#   '근력 약화',
#   '신경절 신경종(Ganglioneuroma)',
#   '고혈압',
#   '신경절 신경종(Ganglioneuroma)',
#   '설사',
#   '신경절 신경종(Ganglioneuroma)',
#   '흉부압박감',
#   '신경절 신경종(Ganglioneuroma)',
#   '무증상'],
#  ['신경절 신경종(Ganglioneuroma)',
#   '발한',
#   '호흡곤란',
#   '근력 약화',
#   '고혈압',
#   '설사',
#   '흉부압박감',
#   '무증상'],
#  ['신경종(Neuroma)', '환부 통증', '신경종(Neuroma)', '환부 부종', '신경종(Neuroma)', '저림'],
#  ['신경종(Neuroma)', '환부 통증', '환부 부종', '저림'],
#  ['신경초종(Schwannoma)',
#   '하지 마비',
#   '신경초종(Schwannoma)',
#   '운동장애',
#   '신경초종(Schwannoma)',
#   '이명',
#   '신경초종(Schwannoma)',
#   '안면마비',
#   '신경초종(Schwannoma)',
#   '삼키기 곤란',
#   '신경초종(Schwannoma)',
#   '청력장애',
#   '신경초종(Schwannoma)',
#   '괄약근 기능 이상'],
#  ['신경초종(Schwannoma)',
#   '하지 마비',
#   '운동장애',
#   '이명',
#   '안면마비',
#   '삼키기 곤란',
#   '청력장애',
#   '괄약근 기능 이상'],
#  ['신체형 장애(Somatic symptom disorder)',
#   '두통',
#   '신체형 장애(Somatic symptom disorder)',
#   '복부팽만감',
#   '신체형 장애(Somatic symptom disorder)',
#   '가슴 쓰림',
#   '신체형 장애(Somatic symptom disorder)',
#   '구토',
#   '신체형 장애(Somatic symptom disorder)',
#   '권태감',
#   '신체형 장애(Somatic symptom disorder)',
#   '근육통',
#   '신체형 장애(Somatic symptom disorder)',
#   '구강건조',
#   '신체형 장애(Somatic symptom disorder)',
#   '얼굴이 화끈거림',
#   '신체형 장애(Somatic symptom disorder)',
#   '가슴 두근거림',
#   '신체형 장애(Somatic symptom disorder)',
#   '가슴 답답',
#   '신체형 장애(Somatic symptom disorder)',
#   '손떨림',
#   '신체형 장애(Somatic symptom disorder)',
#   '온몸이 떨림',
#   '신체형 장애(Somatic symptom disorder)',
#   '오심',
#   '신체형 장애(Somatic symptom disorder)',
#   '생리불순',
#   '신체형 장애(Somatic symptom disorder)',
#   '발한',
#   '신체형 장애(Somatic symptom disorder)',
#   '저림',
#   '신체형 장애(Somatic symptom disorder)',
#   '어지러움'],
#  ['신체형 장애(Somatic symptom disorder)',
#   '두통',
#   '복부팽만감',
#   '가슴 쓰림',
#   '구토',
#   '권태감',
#   '근육통',
#   '구강건조',
#   '얼굴이 화끈거림',
#   '가슴 두근거림',
#   '가슴 답답',
#   '손떨림',
#   '온몸이 떨림',
#   '오심',
#   '생리불순',
#   '발한',
#   '저림',
#   '어지러움'],
#  ['실어증(Aphasia)', '언어장애'],
#  ['실어증(Aphasia)', '언어장애'],
#  ['아스퍼거 증후군(Asperger disorder)',
#   '감각 과민',
#   '아스퍼거 증후군(Asperger disorder)',
#   '대인관계 어려움',
#   '아스퍼거 증후군(Asperger disorder)',
#   '감정 변화'],
#  ['아스퍼거 증후군(Asperger disorder)', '감각 과민', '대인관계 어려움', '감정 변화'],
#  ['악성 신경교종(Malignant Glioma)',
#   '기억장애',
#   '악성 신경교종(Malignant Glioma)',
#   '두통',
#   '악성 신경교종(Malignant Glioma)',
#   '뇌전증 발작'],
#  ['악성 신경교종(Malignant Glioma)', '기억장애', '두통', '뇌전증 발작'],
#  ['안면 마비(Facial palsy)',
#   '청각과민',
#   '안면 마비(Facial palsy)',
#   '발음 이상',
#   '안면 마비(Facial palsy)',
#   '미각이상',
#   '안면 마비(Facial palsy)',
#   '눈물흘림',
#   '안면 마비(Facial palsy)',
#   '안면마비'],
#  ['안면 마비(Facial palsy)', '청각과민', '발음 이상', '미각이상', '눈물흘림', '안면마비'],
#  ['안면인식장애(Prosopagnosia)', '인지장애', '안면인식장애(Prosopagnosia)', '시야장애'],
#  ['안면인식장애(Prosopagnosia)', '인지장애', '시야장애'],
#  ["알츠하이머병(Alzheimer's disease)",
#   '기억장애',
#   "알츠하이머병(Alzheimer's disease)",
#   '우울',
#   "알츠하이머병(Alzheimer's disease)",
#   '감정 변화',
#   "알츠하이머병(Alzheimer's disease)",
#   '실인증',
#   "알츠하이머병(Alzheimer's disease)",
#   '방향감각 상실',
#   "알츠하이머병(Alzheimer's disease)",
#   '언어장애',
#   "알츠하이머병(Alzheimer's disease)",
#   '실행증',
#   "알츠하이머병(Alzheimer's disease)",
#   '조급증',
#   "알츠하이머병(Alzheimer's disease)",
#   '섬망',
#   "알츠하이머병(Alzheimer's disease)",
#   '판단력장애',
#   "알츠하이머병(Alzheimer's disease)",
#   '시력 감소'],
#  ["알츠하이머병(Alzheimer's disease)",
#   '기억장애',
#   '우울',
#   '감정 변화',
#   '실인증',
#   '방향감각 상실',
#   '언어장애',
#   '실행증',
#   '조급증',
#   '섬망',
#   '판단력장애',
#   '시력 감소'],
#  ['알코올 의존성(Dependance of alcohol)',
#   '반사회적 인격장애',
#   '알코올 의존성(Dependance of alcohol)',
#   '금단증상',
#   '알코올 의존성(Dependance of alcohol)',
#   '불안'],
#  ['알코올 의존성(Dependance of alcohol)', '반사회적 인격장애', '금단증상', '불안'],
#  ['양극성 장애(Bipolar disorder)',
#   '사고의 비약',
#   '양극성 장애(Bipolar disorder)',
#   '우울',
#   '양극성 장애(Bipolar disorder)',
#   '망상',
#   '양극성 장애(Bipolar disorder)',
#   '말을 많이 함',
#   '양극성 장애(Bipolar disorder)',
#   '높아진 자존심'],
#  ['양극성 장애(Bipolar disorder)', '사고의 비약', '우울', '망상', '말을 많이 함', '높아진 자존심'],
#  ['얼렌 증후군(Irlen syndrome)',
#   '눈의 충혈',
#   '얼렌 증후군(Irlen syndrome)',
#   '광과민성',
#   '얼렌 증후군(Irlen syndrome)',
#   '읽기 자체의 문제',
#   '얼렌 증후군(Irlen syndrome)',
#   '읽으려 하지 않음',
#   '얼렌 증후군(Irlen syndrome)',
#   '눈의 피로'],
#  ['얼렌 증후군(Irlen syndrome)',
#   '눈의 충혈',
#   '광과민성',
#   '읽기 자체의 문제',
#   '읽으려 하지 않음',
#   '눈의 피로'],
#  ['외상 후 스트레스 장애(Post-traumatic stress disorder)',
#   '불안',
#   '외상 후 스트레스 장애(Post-traumatic stress disorder)',
#   '수면장애',
#   '외상 후 스트레스 장애(Post-traumatic stress disorder)',
#   '대인관계 어려움'],
#  ['외상 후 스트레스 장애(Post-traumatic stress disorder)', '불안', '수면장애', '대인관계 어려움'],
#  ['외상성 경막하 출혈(Traumatic subdural hemorrhage)',
#   '혼수',
#   '외상성 경막하 출혈(Traumatic subdural hemorrhage)',
#   '두통',
#   '외상성 경막하 출혈(Traumatic subdural hemorrhage)',
#   '반신마비',
#   '외상성 경막하 출혈(Traumatic subdural hemorrhage)',
#   '호흡곤란',
#   '외상성 경막하 출혈(Traumatic subdural hemorrhage)',
#   '구토'],
#  ['외상성 경막하 출혈(Traumatic subdural hemorrhage)',
#   '혼수',
#   '두통',
#   '반신마비',
#   '호흡곤란',
#   '구토'],
#  ['외상성 치매 (Traumatic dementia)',
#   '인지장애',
#   '외상성 치매 (Traumatic dementia)',
#   '기억장애',
#   '외상성 치매 (Traumatic dementia)',
#   '변실금',
#   '외상성 치매 (Traumatic dementia)',
#   '성격의변화',
#   '외상성 치매 (Traumatic dementia)',
#   '언어장애'],
#  ['외상성 치매 (Traumatic dementia)', '인지장애', '기억장애', '변실금', '성격의변화', '언어장애'],
#  ['외상에 의한 뇌 손상(Traumatic brain injury)',
#   '오심',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '피로감',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '감각 과민',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '구토',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '어지러움',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '의식 변화',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '기억장애',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '두통',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '경련',
#   '외상에 의한 뇌 손상(Traumatic brain injury)',
#   '혼수'],
#  ['외상에 의한 뇌 손상(Traumatic brain injury)',
#   '오심',
#   '피로감',
#   '감각 과민',
#   '구토',
#   '어지러움',
#   '의식 변화',
#   '기억장애',
#   '두통',
#   '경련',
#   '혼수'],
#  ['외상에 의한 척수 손상(Traumatic Spinal cord injury)',
#   '배뇨장애',
#   '외상에 의한 척수 손상(Traumatic Spinal cord injury)',
#   '발진',
#   '외상에 의한 척수 손상(Traumatic Spinal cord injury)',
#   '장마비',
#   '외상에 의한 척수 손상(Traumatic Spinal cord injury)',
#   '서호흡'],
#  ['외상에 의한 척수 손상(Traumatic Spinal cord injury)', '배뇨장애', '발진', '장마비', '서호흡'],
#  ['요추 추간판 탈출증(Herniation of intervertebral disk)',
#   '감각 이상',
#   '요추 추간판 탈출증(Herniation of intervertebral disk)',
#   '다리 통증',
#   '요추 추간판 탈출증(Herniation of intervertebral disk)',
#   '하지 마비',
#   '요추 추간판 탈출증(Herniation of intervertebral disk)',
#   '저림',
#   '요추 추간판 탈출증(Herniation of intervertebral disk)',
#   '요통'],
#  ['요추 추간판 탈출증(Herniation of intervertebral disk)',
#   '감각 이상',
#   '다리 통증',
#   '하지 마비',
#   '저림',
#   '요통'],
#  ['우울증(Depressive disorder)',
#   '수면장애',
#   '우울증(Depressive disorder)',
#   '삶에 대한 흥미 상실',
#   '우울증(Depressive disorder)',
#   '환각',
#   '우울증(Depressive disorder)',
#   '자살의 위험',
#   '우울증(Depressive disorder)',
#   '식욕부진',
#   '우울증(Depressive disorder)',
#   '오후 우울감 완화',
#   '우울증(Depressive disorder)',
#   '망상'],
#  ['우울증(Depressive disorder)',
#   '수면장애',
#   '삶에 대한 흥미 상실',
#   '환각',
#   '자살의 위험',
#   '식욕부진',
#   '오후 우울감 완화',
#   '망상'],
#  ['운동신경 질환(Motor neuron disease)',
#   '기침',
#   '운동신경 질환(Motor neuron disease)',
#   '호흡곤란',
#   '운동신경 질환(Motor neuron disease)',
#   '체중감소',
#   '운동신경 질환(Motor neuron disease)',
#   '근력 약화',
#   '운동신경 질환(Motor neuron disease)',
#   '삼키기 곤란',
#   '운동신경 질환(Motor neuron disease)',
#   '파행',
#   '운동신경 질환(Motor neuron disease)',
#   '근육경련'],
#  ['운동신경 질환(Motor neuron disease)',
#   '기침',
#   '호흡곤란',
#   '체중감소',
#   '근력 약화',
#   '삼키기 곤란',
#   '파행',
#   '근육경련'],
#  ['윌슨병(Willson disease)',
#   '삼키기 곤란',
#   '윌슨병(Willson disease)',
#   '간부전',
#   '윌슨병(Willson disease)',
#   '복부팽만감',
#   '윌슨병(Willson disease)',
#   '간기능 저하',
#   '윌슨병(Willson disease)',
#   '피로감',
#   '윌슨병(Willson disease)',
#   '간성뇌증',
#   '윌슨병(Willson disease)',
#   '무월경',
#   '윌슨병(Willson disease)',
#   '황달',
#   '윌슨병(Willson disease)',
#   '관절통',
#   '윌슨병(Willson disease)',
#   '빈혈',
#   '윌슨병(Willson disease)',
#   '떨림(진전)',
#   '윌슨병(Willson disease)',
#   '혈뇨'],
#  ['윌슨병(Willson disease)',
#   '삼키기 곤란',
#   '간부전',
#   '복부팽만감',
#   '간기능 저하',
#   '피로감',
#   '간성뇌증',
#   '무월경',
#   '황달',
#   '관절통',
#   '빈혈',
#   '떨림(진전)',
#   '혈뇨'],
#  ['의상도착증(Transvestic fetishism)', '이성의 옷을 착용함'],
#  ['의상도착증(Transvestic fetishism)', '이성의 옷을 착용함'],
#  ['이차성 파킨슨증(Other parkinsonism)',
#   '연속동작의 느림',
#   '이차성 파킨슨증(Other parkinsonism)',
#   '떨림(진전)',
#   '이차성 파킨슨증(Other parkinsonism)',
#   '서동',
#   '이차성 파킨슨증(Other parkinsonism)',
#   '근육강직'],
#  ['이차성 파킨슨증(Other parkinsonism)', '연속동작의 느림', '떨림(진전)', '서동', '근육강직'],
#  ['인터넷 중독(Internet addiction)',
#   '대인관계 어려움',
#   '인터넷 중독(Internet addiction)',
#   '강박증',
#   '인터넷 중독(Internet addiction)',
#   '조절할 수 없는 충동감',
#   '인터넷 중독(Internet addiction)',
#   '충동 조절 어려움',
#   '인터넷 중독(Internet addiction)',
#   '낮은 학업 성취',
#   '인터넷 중독(Internet addiction)',
#   '산만함'],
#  ['인터넷 중독(Internet addiction)',
#   '대인관계 어려움',
#   '강박증',
#   '조절할 수 없는 충동감',
#   '충동 조절 어려움',
#   '낮은 학업 성취',
#   '산만함'],
#  ['일과성 뇌허혈증(Transient cerebral ischemia)',
#   '감각 이상',
#   '일과성 뇌허혈증(Transient cerebral ischemia)',
#   '구토',
#   '일과성 뇌허혈증(Transient cerebral ischemia)',
#   '안면마비',
#   '일과성 뇌허혈증(Transient cerebral ischemia)',
#   '파행',
#   '일과성 뇌허혈증(Transient cerebral ischemia)',
#   '어지러움',
#   '일과성 뇌허혈증(Transient cerebral ischemia)',
#   '언어장애'],
#  ['일과성 뇌허혈증(Transient cerebral ischemia)',
#   '감각 이상',
#   '구토',
#   '안면마비',
#   '파행',
#   '어지러움',
#   '언어장애'],
#  ['일본 뇌염(Japanese encephalitis)',
#   '무증상',
#   '일본 뇌염(Japanese encephalitis)',
#   '두통',
#   '일본 뇌염(Japanese encephalitis)',
#   '혼수',
#   '일본 뇌염(Japanese encephalitis)',
#   '열',
#   '일본 뇌염(Japanese encephalitis)',
#   '의식 변화',
#   '일본 뇌염(Japanese encephalitis)',
#   '경련',
#   '일본 뇌염(Japanese encephalitis)',
#   '구토',
#   '일본 뇌염(Japanese encephalitis)',
#   '감각 이상'],
#  ['일본 뇌염(Japanese encephalitis)',
#   '무증상',
#   '두통',
#   '혼수',
#   '열',
#   '의식 변화',
#   '경련',
#   '구토',
#   '감각 이상'],
#  ['자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)',
#   '구토',
#   '자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)',
#   '두통',
#   '자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)',
#   '의식 변화',
#   '자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)',
#   '어지러움',
#   '자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)',
#   '고혈압',
#   '자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)',
#   '편마비'],
#  ['자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)',
#   '구토',
#   '두통',
#   '의식 변화',
#   '어지러움',
#   '고혈압',
#   '편마비'],
#  ['자폐증 / 자폐 스펙트럼 장애(Autism spectrum disorder)',
#   '언어장애',
#   '자폐증 / 자폐 스펙트럼 장애(Autism spectrum disorder)',
#   '정신 지체',
#   '자폐증 / 자폐 스펙트럼 장애(Autism spectrum disorder)',
#   '사회적 고립',
#   '자폐증 / 자폐 스펙트럼 장애(Autism spectrum disorder)',
#   '상동적 행동'],
#  ['자폐증 / 자폐 스펙트럼 장애(Autism spectrum disorder)',
#   '언어장애',
#   '정신 지체',
#   '사회적 고립',
#   '상동적 행동'],
#  ['잠금 증후군(Locked-in Syndrome)',
#   '눈운동신경마비',
#   '잠금 증후군(Locked-in Syndrome)',
#   '안구 이상',
#   '잠금 증후군(Locked-in Syndrome)',
#   '인지장애',
#   '잠금 증후군(Locked-in Syndrome)',
#   '사지 마비',
#   '잠금 증후군(Locked-in Syndrome)',
#   '기억장애',
#   '잠금 증후군(Locked-in Syndrome)',
#   '뇌압상승증상',
#   '잠금 증후군(Locked-in Syndrome)',
#   '언어장애'],
#  ['잠금 증후군(Locked-in Syndrome)',
#   '눈운동신경마비',
#   '안구 이상',
#   '인지장애',
#   '사지 마비',
#   '기억장애',
#   '뇌압상승증상',
#   '언어장애'],
#  ['적응 장애(Adjustment disorder)',
#   '우울',
#   '적응 장애(Adjustment disorder)',
#   '희망이 없는 느낌',
#   '적응 장애(Adjustment disorder)',
#   '걸핏하면 눈물지음'],
#  ['적응 장애(Adjustment disorder)', '우울', '희망이 없는 느낌', '걸핏하면 눈물지음'],
#  ['조현병(정신분열병)(schizophrenia)',
#   '무논리증',
#   '조현병(정신분열병)(schizophrenia)',
#   '망상',
#   '조현병(정신분열병)(schizophrenia)',
#   '무욕증',
#   '조현병(정신분열병)(schizophrenia)',
#   '와해된 언어',
#   '조현병(정신분열병)(schizophrenia)',
#   '환각',
#   '조현병(정신분열병)(schizophrenia)',
#   '와해된 행동',
#   '조현병(정신분열병)(schizophrenia)',
#   '피해망상',
#   '조현병(정신분열병)(schizophrenia)',
#   '정서적 둔마'],
#  ['조현병(정신분열병)(schizophrenia)',
#   '무논리증',
#   '망상',
#   '무욕증',
#   '와해된 언어',
#   '환각',
#   '와해된 행동',
#   '피해망상',
#   '정서적 둔마'],
#  ['좌골신경통(Sciatica)',
#   '골반 통증',
#   '좌골신경통(Sciatica)',
#   '저림',
#   '좌골신경통(Sciatica)',
#   '다리 통증',
#   '좌골신경통(Sciatica)',
#   '요통'],
#  ['좌골신경통(Sciatica)', '골반 통증', '저림', '다리 통증', '요통'],
#  ...]

# %%
# 질병 리스트와 증상 리스트 초기화
disease_list = []
symptom_list = []

# 각 행(질병)에 대해 반복
for index, row in df.iterrows():
    # 질병명 추가
    disease_name = row['disease_name']
    if disease_name not in disease_list:
        disease_list.append(disease_name)
    
    # 증상 추가
    symptoms = row['symptoms'].split(', ')
    for symptom in symptoms:
        if symptom not in symptom_list:
            symptom_list.append(symptom)
# Out:
# 질병 리스트:
# RS바이러스 감염증(RS virus infection)
# 각막염(Keratitis)
# 간농양(Liver abscess)
# 감염성 근육염(Infective myositis)
# 감염성 단핵구증(Infectious mononucleosis)
# 감염성 홍반(Erythema infectiosum)
# 거대세포 바이러스 질환(Cytomegaloviral diseases)
# 결막염(Conjunctivitis)
# 결핵(Tuberculosis)
# 결핵성 골수염(Tuberculous osteomyelitis)
# 결핵성 복막염(Tuberculous peritonitis)
# 결핵성 수막염(Tuberculous meningitis)
# 결핵성 임파선염(Tuberculous lymphadenitis)
# 경부 림프절염(Cervical lymphadenitis)
# 곰팡이 감염(Fungal infection)
# 광견병(Rabies)
# 광우병(Bovine spongiform encephalopathy)
# 구순염(Cheilitis)
# 구순포진(Herpes labialis)
# 급성 바이러스성 간염(Acute viral hepatitis)
# 급성 위장염(Acute gastroenteritis)
# 급성 질염(Acute vaginitis)
# 기쿠치병(Kikuchi Disease)
# 난소난관염(Oophoritis, Ovaritis)
# 노로바이러스 장염(Norovirus Gastroenteritis)
# 노카르디아증(Nocardiosis)
# 뇌농양(Brain abscess)
# 뇌염(Encephalitis)
# 단독(Erysipelas)
# 단순 포진(Herpes Simplex)
# 단순 포진성 뇌염(Herpes simplex encephalitis)
# 대상포진(Herpes zoster)
# 대상포진 후 신경통(Postzoster neuralgia)
# 대장균 감염(Escherichia coli (E. coli) infection)
# 뎅기열(Dengue fever)
# 돌발성 발진(Exanthem subitum)
# 두부 백선(Tinea Capitis)
# 두통(Headache)
# 디프테리아(Diphtheritia)
# 라싸열(Lassa fever )
# 라임병(Lyme disease)
# 레지오넬라증(Legionella)
# 렙토스피라증(Leptospirosis)
# 리스테리아(Listeria)
# 마버그열(Marburg hemorrhagic fever)
# 만성 C형 간염(Chronic hepatitis C)
# 말라리아(Malaria)
# 매독(Syphilis)
# 메리오이드증(Melioidosis)
# 무른 궤양(Chancroid)
# 바이러스성 뇌수막염(Viral meningitis)
# 박테리아성 뇌수막염(Bacterial meningitis)
# 반코마이신 내성 장알균(VRE) 감염증(Vancomycin-Resistant Enterococci)
# 반코마이신 내성 황색포도알균(VRSA) 감염증(Vancomycin-Resistant Staphylococcus aureus)
# 발진열(Murine typhus)
# 발진티푸스(Epidemic typhus)
# 방선균증(Actinomycosis)
# 백일해(Pertussis)
# 베게너 육아종증(Wegener granulomatosis)
# 병원 감염성 폐렴(Hospital acquired pneumonia (HAP))
# 보툴리눔독소증(Botulism)
# 브루셀라증(Brucellosis)
# 비브리오 패혈증(Vibrio vulnificus Septicemia)
# 사마귀(Wart)
# 사면발이증(Pediculosis pubis)
# 사타구니 백선(Tinea cruris)
# 상기도 감염(Upper respiratory infections)
# 샅(서혜)육아종(Granuloma inguinale)
# 샤가스병(Chagas disease)
# 선모충증(Trichinellosis)
# 성병(Sexually transmitted disease)
# 성홍열(Scarlet fever)
# 세균성 이질(Shigellosis)
# 소아마비(Polio)
# 속립성 결핵(Miliary tuberculosis)
# 수두(Varicella (chickenpox))
# 수족구병(Hand, foot and mouth disease)
# 슈도모나스 감염(Pseudomonas infection)
# 스파르가눔증(Sparganosis)
# 신생아 괴사성 장염(Necrotizing enterocolitis of fetus and newborn)
# 신종 플루(Novel swine-origin influenza A(H1N1))
# 신증후성 출혈열(Hemorrhagic fever with renal syndrome)
# 심내막염(Endocarditis)
# 아메바성 이질(Amebic dysentery)
# 아스페르길루스증(Aspergillosis)
# 야토병(Tularemia)
# 에볼라 출혈열(Ebola hemorrhagic fever)
# 옻 중독(Poison ivy dermatitis)
# 요근 농양(Psoas abscess)
# 요충증(Enterobiasis)
# 용혈성 요독 증후군(Hemolytic Uremic Syndrome)
# 원인을 알 수 없는 열(Fever of unknown origin)
# 원충성 질환(PROTOZOAL DISEASES)
# 웨스트나일열(West Nile Fever)
# 위장관 결핵(Gastrointestinal tuberculosis)
# 유행성 이하선염(Mumps)
# 인유두종 바이러스 감염증(Human papiloma virus infection)
# 인플루엔자(Influenza)
# 일본 뇌염(Japanese encephalitis)
# 임파선염(Lymphadenitis)
# 자궁경부염(Cervicitis)
# 장출혈성 대장균 감염증(Enterohemorrhagic Escherichia coli)
# 장티푸스(typhoid fever)
# 조갑주위염(Paronychia)
# 조류 인플루엔자(AI) 인체감염증(Avian Influenza Human Infection)
# 중동 호흡기 증후군(MERS)(Middle East Respiratory Syndrome)
# 중증 급성 호흡기 증후군(Severe Acute Respiratory Syndrom)
# 중증 열성 혈소판감소 증후군(Severe fever with thrombocytopenia syndrome(SFTS))
# 증상이 없는 HIV 감염(HIV infection, asymptomatic)
# 지역사회성 폐렴(Community acquired pneumonia)
# 지카 바이러스 감염증(Zikavirus Infection)
# 첨형 콘딜로마(Condyloma accuminatum)
# 치쿤구니야열(Chikungunya Fever)
# 칸디다성 구내염(Candidal stomatitis)
# 캄필로박터 감염증(Campylobacteriosis)
# 코로나-19(COVID-19)
# 콜레라(Cholera)
# 큐열(Q Fever)
# 크로이츠펠트-야콥병(Creutzfeldt-Jakob disease)
# 탄저병(Anthrax)
# 털진드기병(Scrub typhus)
# 톡소플라즈마증(Toxoplasmosis)
# 파라인플루엔자 감염증(Parainfluenza infection)
# 파라티푸스(Paratyphoid fever)
# 파상풍(Tetanus)
# 패혈성 관절염(Septic arthtritis)
# 패혈증(Sepsis)
# 폐결핵(Pulmonary tuberculosis)
# 폐색성 혈전 혈관염 (Thromboangiitis obliterans)
# 포도상구균 감염(Staphylococcus aureus infection)
# 풍진(Rubella(German measles))
# 한센병(Leprosy)
# 헤르페스 바이러스 감염(Herpesviral infection)
# 호산구 증가증(Eosinophilia)
# 홍역(Measles)
# 황열(Yellow fever)
# 효모균증(Cryptococcosis)
# 후두개염(Epiglottitis)
# 후천성 면역결핍증(Acquired immunodeficiency syndrome)
# 흑사병(Yersinia Pestis)
# 히스토플라즈마증(Histoplasmosis)
# 고혈압(Essential (primary) hypertension)
# 괴혈병(scurvy)
# 근감소증(Sarcopenia)
# 납 중독(Lead Poisoning)
# 냉방병(Air-conditioningitis)
# 노쇠(Frailty)
# 노화(Senility)
# 대사 증후군(Metabolic syndrome)
# 만성 피로 증후군(Chronic Fatigue Syndrome)
# 비만(Obesity)
# 새집 증후군(Sick building syndrome)
# 알코올성 간질환(Alcoholic liver disease)
# 이상지질혈증(Dyslipidemia)
# 지방간(Fatty liver)
# 춘곤증(spring fatigue)
# 폐경(Menopause)
# 해외여행 시 주의사항(Travel counseling)
# 감각신경성 난청(Sensorineural hearing loss)
# 고막염(Myringitis)
# 구강암(Oral Cancer)
# 급성 중이염(Acute otitis media)
# 꽃가루 알레르기(Pollen allergy)
# 난청(hearing loss)
# 낭포성 히그로마(Cystic hygroma)
# 노인성 난청(Presbycusis)
# 루드비히 안자이나 (Ludwig's angina)
# 만성 부비동염(Chronic rhinosinusitis)
# 만성 비염(Chronic rhinitis)
# 만성 중이염(Chronic otitis media)
# 매몰귀(Cryptotia)
# 메니에르병(Meniere's disease)
# 미로염(Labyrinthitis)
# 부비동염(Sinusitis)
# 비부비동 종양(Sinonasal Tumor)
# 비용종(Nasal polyp)
# 비인두 종양(Nasopharyngeal tumor)
# 비중격 만곡(Nasal septal deviation)
# 비출혈(Epistaxis)
# 산후 갑상선염(Postpartum thyroiditis)
# 삼출성 중이염(Otitis media with effusion)
# 성대와 후두 결절(Nodules of vocal cord and larynx)
# 성대와 후두 용종(Polyps of vocal cord and larynx)
# 수면 무호흡증(Sleep apnea)
# 아나필락시스(Anaphylactic shock)
# 아데노이드의 비대를 동반한 편도의 비대(Hypertrophy of tonsils with hypertrophy of adenoids)
# 알레르기 비염(Allergic rhinitis)
# 외상에 의한 고막 천공(Traumatic rupture of ear drum [Traumatic tympanic membrane perforation])
# 외이도염(Otitis externa)
# 이루증(Otorrhea)
# 이석증(Benign paroxysmal vertigo)
# 인후두염(Laryngopharyngitis)
# 전정신경염(Vestibular neuronitis)
# 진주종(Cholesteatoma)
# 청신경초종(Vestibular schwannoma)
# 타석증(Sialolithiasis)
# 타액선암(Malignant neoplasm of salivary glands)
# 편도결석(tonsillolith)
# 편도선염(Tonsillitis)
# 편도암(Tonsillar cancer)
# 현훈(Vertigo)
# 후각장애, 미각장애(Anosmia, Hyposmia)
# 후두암(Larynx  cancer)
# 후비루(Postnasal drip)
# VDT 증후군(Visual Display Terminal Syndrome)
# 가스 괴저(Gas gangrene)
# 각기병(Beriberi)
# 강직성 척추염(Ankylosing spondylitis)
# 거북목 증후군(Turtle neck syndrome)
# 건 손상(Tendon injury)
# 건초염(Tenosynovitis)
# 결절종(Ganglion)
# 경골과 비골 골절(Fracture of tibia & fibula)
# 고관절 이형성증(DDH (developmental dysplasia of the hip))
# 골감소증(Osteopenia)
# 골관절염(Osteoarthritis)
# 골괴사(Osteonecrosis)
# 골수염(Osteomyelitis)
# 골육종(Osteosarcoma)
# 골절 후 부정 유합, 불유합(Malunion & nonunion of fracture)
# 관절염(Arthritis)
# 관절와순 파열(Labral tear)
# 구루병(Rickets)
# 구획 증후군(Compartment syndrome)
# 근근막 통증 증후군(myofascial pain syndrome)
# 근육병(Myopathy)
# 내반슬(Bow leg)
# 내상과염(Golf Elbow)
# 내연골종(Enchondroma)
# 노인성 척추후만증(Senile Kyphosis)
# 대퇴 골절(Fracture of femur)
# 대퇴골두 무혈관성 괴사(AVN of hip(femoral head))
# 동결견(Frozen shoulder)
# 두개 유합증(Craniosynostosis)
# 두개골 골절(Skull Fracture)
# 듀시엔형 근이영양증 (Duchenne muscular dystrophy)
# 듀피트렌 구축(Dupuytren's contracture)
# 류마티스 관절염(Rheumatoid arthritis)
# 망치족지(Hammer toe)
# 무릎관절증(Gonarthrosis)
# 무지(엄지)중수지관절측부인대손상(Gamekeeper's thumb)
# 무지외반증(Hallux valgus)
# 반달연골 이상(Meniscus derangements)
# 반월판 연골손상(Tear of meniscus)
# 방아쇠 수지(Trigger finger)
# 베이커 낭종(Baker's cyst)
# 베체트 병(Behcet's disease)
# 변형성 고관절증(Coxarthrosis)
# 병리적 골절(Pathological fracture)
# 복합 부위 통증 증후군(Complex regional pain syndrome)
# 부가지(Accessory toe)
# 뼈의 신생물(Neoplasm of the bone)
# 석회성 건염(Calcific Tendinitis)
# 선천성 사경(Congenital (sternomastoid) torticollis)
# 선천성 편평발(Congenital pes planus [flat foot])
# 섬유근육통(Fibromyalgia)
# 소건막류(Bunionette)
# 소아 류마티스 관절염(Juvenile rheumatoid arthritis)
# 손목 수근관 증후군(Carpal tunnel syndrome)
# 쇄골 골절(Clavicle Fracture)
# 수부 외상(Hand trauma)
# 슬개건염(Patellar tendinitis)
# 슬개골 골절(Patella Fracture)
# 슬관절 장애(Internal derangement of knee)
# 십자 인대 손상(Cruciate Ligament Injuries)
# 아킬레스 건 파열(Acute achilles tendon rupture)
# 아킬레스 건염(Achilles' tendonitis)
# 안면 골절(Facial bone fracture)
# 안와 골절(orbital fracture)
# 압궤 손상(Crushing injury)
# 연골연화증(Chondromalacia)
# 연부조직 육종(Soft tissue sarcoma)
# 염좌(sprain)
# 오스굿씨 병(Osgood Schlatter Disease)
# 완전 척수 손상(Complete cord injury)
# 외반슬(Knock-knee)
# 외상에 의한 척추 손상(Traumatic spine injury)
# 요족(Cavus foot)
# 요추 전방전위증(Lumbar spondylolisthesis)
# 요추 추간판 탈출증(Herniation of intervertebral disk)
# 요추관 협착증(Lumbar spinal stenosis)
# 요통(Low back pain)
# 원위 요골과 척골 골절(Fracture of distal radius and ulna)
# 원판형 반월상연골(Discoid meniscus)
# 육종(Sarcoma)
# 이소성 골화증(Heterotopic Ossification)
# 일과성 고관절 활액막염(Transient synovitis of hip)
# 재발성 견관절 전방 탈구(Recurrent Anterior Glenohumeral Dislocation)
# 전신 경화증(Systemic Sclerosis)
# 점액낭염(Bursitis)
# 족저 근막염(Plantar Fasciitis)
# 좌골신경통(Sciatica)
# 주관절 외상과염(Tennis Elbow)
# 지간 신경종(Interdigital neuroma)
# 지방종(Lipoma)
# 척수공동증(Syringomyelia)
# 척수구근 근위축증 (Spinobulbar muscular atrophy)
# 척추 골수염(Vertebral osteomyelitis)
# 척추 종양(Spine Bone Tumor)
# 척추병증(Spondylopathies)
# 척추측만증(Scoliosis)
# 천추골 골절(sacral fracture)
# 턱관절 장애(Temporomandibular joint disorders)
# 통풍(Gout)
# 통풍성 관절염(gouty arthritis)
# 퇴행성 척추 장애(Degenerative spinal disorder)
# 팔죽지 골절(Humerus fracture)
# 피로 골절(Stress fracture)
# 피부근육염(Dermatopolymyositis)
# 회전근개 증후군(Rotator cuff syndrome)
# 횡단성 척수염(Transverse myelitis)
# 횡문근육종(Rhabdomyosarcoma)
# 횡문근융해증(Rhabdomyolysis)
# 후종인대 골화증(Ossification of posterior longitudinal ligament)
# 가성근시(Pseudomyopia)
# 각막 궤양(Corneal ulcer)
# 각막 혼탁과 흉터(Corneal opacity and scar)
# 근시(Myopia)
# 난시(Astigmatism)
# 노안(Presbyopia)
# 녹내장(Glaucoma)
# 눈꺼풀 장애(Disorders of eyelid)
# 눈물흘림증(Epiphora)
# 당뇨망막병증(Diabetic retinopathy)
# 망막 박리(Retinal detachments & breaks)
# 망막 열공(retina tear)
# 망막 전막(Epiretinal membrane)
# 망막 정맥 폐쇄(Retinal vein occlusion)
# 망막 출혈(Retinal hemorrhage)
# 망막색소변성증(Retinitis Pigmentosa)
# 망막아세포종(Retinoblastoma)
# 맥락막 흑색종(Choroidal melanoma)
# 맥립종(Stye)
# 미숙아 망막병증(Retinopathy of Prematurity)
# 백내장(Cataract)
# 복시(Diplopia)
# 비루관 폐쇄(Nasolacrimal duct obstruction)
# 비문증(Floaters)
# 사시(Strabismus)
# 색약(color amblyopia)
# 선천성 눈 기형(Congenital malformations of eye)
# 설맹(Snow blindness)
# 수정체 탈구(Lens luxation)
# 스티븐 존슨 증후군(Stevens Johnson syndrome)
# 시신경염(Optic neuritis)
# 안검내반(Entropion)
# 안검염(Blepharitis)
# 안검하수(Ptosis of eyelid)
# 안구 건조증(Dry eye syndrome)
# 안암(eye cancer)
# 알레르기성 결막염(Allergic conjunctivitis)
# 야맹증(Night blindness)
# 약시(Amblyopia)
# 원추각막(Keratoconus)
# 유리체 출혈(Vitreous hemorrhage)
# 익상편(Pterygium)
# 중심장액성 맥락망막병증(Central Serous ChorioRetinopathy)
# 진균성 각막 궤양(Fungal corneal ulcers)
# 출혈성 결막염(Hemorrhagic conjunctivitis)
# 포도막염(Uveitis)
# 홍채염(Iritis)
# 화농성 안구내염(Purulent Endophthalmitis)
# 황반변성(Macular degeneration)
# 황반천공(Macular hole)
# 강박 장애(Obsessive-Compulsive Disorder)
# 거스트만 증후군(Gerstmann Syndrome)
# 건강염려증(Hypochondriasis)
# 경계성 인격장애(Borderline personality disorder)
# 경미한 인지장애(Mild cognitive impairment)
# 경추 추간판 탈출증(Cervical HIVD)
# 공황 장애(Panic disorder)
# 과호흡 증후군(Hyperventilation syndrome)
# 광장공포증(Agoraphobia)
# 교모세포종(Glioblastoma)
# 군발성 두통 증후군(Cluster headache syndrome)
# 근위축성 측색 경화증(Amyotrophic lateral sclerosis)
# 근육 긴장성 두통(Tension-type headache)
# 근육긴장이상증(Dystonia)
# 금단 현상(Withdrawal Phenomenon)
# 기면증(Narcolepsy)
# 기분부전증(Dysthymia)
# 기억상실증(amnesia)
# 길랑-바레 증후군(Guillain-Barre Syndrome)
# 난독증(Dyslexia)
# 뇌 동정맥 기형(Cerebral arteriovenous malformation)
# 뇌경색(Cerebral infarction)
# 뇌동맥 폐쇄(Occlusion of cerebral artery)
# 뇌동맥류(Cerebral aneurysm)
# 뇌사(brain death)
# 뇌성 마비(Cerebral palsy)
# 뇌전증(Epilepsy)
# 뇌졸중(Cerebrovascular disease)
# 뇌종양(Brain tumor)
# 뇌출혈(Cerebral hemorrhage)
# 뇌하수체 양성 및 악성 신생물(Malignant or benign neoplasm of Pituitary gland)
# 다발성 경화증(Multiple sclerosis)
# 다발성 신경병증(Polyneuropathy)
# 당뇨병성 말초신경병증(Diabetic polyneuropathy)
# 대뇌성 거인증 (Sotos syndrome)
# 떨림, 진전(Tremor)
# 뚜렛 증후군(Tourette Syndrome)
# 레이노병(Raynaud'S Phenomenon)
# 말단비대증(Acromegaly)
# 말더듬이(Stuttering)
# 말초동맥질환(Peripheral aterial disease, PAD)
# 망상 장애(Delusional disorder)
# 모야모야병(Moyamoya disease)
# 뮌하우젠 증후군(Munchausen's syndrome)
# 반사회성 인격장애(Antisocial Personality Disorder)
# 반응성 애착장애(Reactive Attachment Disorder)
# 발달 장애(developmental disability)
# 발모벽(Trichotillomania)
# 발작(Seizure)
# 베르니케 코시코프 증후군(Wernicke-korsakoff syndrome)
# 병적 도벽(Pathological stealing)
# 병적 방화(Pathological fire-setting)
# 보행 운동 장애(Abnormalities of gait and mobility)
# 분리 불안 장애(Separation Anxiety Disorder)
# 분열정동 장애(Schizoaffective disorders)
# 불면증(Insomnia)
# 불안 장애(Anxiety disorder)
# 비정형 파킨슨 증후군(Atypical Parkinsonism)
# 사회공포증(Sociophobia)
# 산후 우울증(Postpartum depression)
# 삼차 신경병증(Trigeminal neuralgia)
# 설인신경통(Glossopharyngeal neuralgia)
# 섬망(Delirium)
# 섭식 장애(Eating disorder)
# 성기능장애(Sexual dysfunctions)
# 성도착증(Paraphilia)
# 성인 주의력 결핍 과잉행동장애(Adult attention-deficit hyperactivity disorder)
# 소아청소년기 우울증(Depression in childhood and adolescence)
# 수두증(Hydrocephalus)
# 수막종(Meningioma)
# 수면 장애(Sleep Disorder)
# 수면보행증(Somnambulism)
# 스터지 웨버 증후군(Sturge Weber Syndrome)
# 스핑고 지질증(Other sphingolipidosis)
# 신경근병증(Radiculopathy)
# 신경섬유종(Neurofibromatosis)
# 신경성 식욕부진증(Anorexia nervosa)
# 신경성 폭식증(Bulimia nervosa)
# 신경절 신경종(Ganglioneuroma)
# 신경종(Neuroma)
# 신경초종(Schwannoma)
# 신체형 장애(Somatic symptom disorder)
# 실어증(Aphasia)
# 아스퍼거 증후군(Asperger disorder)
# 악성 신경교종(Malignant Glioma)
# 안면 마비(Facial palsy)
# 안면인식장애(Prosopagnosia)
# 알츠하이머병(Alzheimer's disease)
# 알코올 의존성(Dependance of alcohol)
# 양극성 장애(Bipolar disorder)
# 얼렌 증후군(Irlen syndrome)
# 외상 후 스트레스 장애(Post-traumatic stress disorder)
# 외상성 경막하 출혈(Traumatic subdural hemorrhage)
# 외상성 치매 (Traumatic dementia)
# 외상에 의한 뇌 손상(Traumatic brain injury)
# 외상에 의한 척수 손상(Traumatic Spinal cord injury)
# 우울증(Depressive disorder)
# 운동신경 질환(Motor neuron disease)
# 윌슨병(Willson disease)
# 의상도착증(Transvestic fetishism)
# 이차성 파킨슨증(Other parkinsonism)
# 인터넷 중독(Internet addiction)
# 일과성 뇌허혈증(Transient cerebral ischemia)
# 자발성 두개강 내 출혈(Spontaneous intracranial hemorrhage)
# 자폐증 / 자폐 스펙트럼 장애(Autism spectrum disorder)
# 잠금 증후군(Locked-in Syndrome)
# 적응 장애(Adjustment disorder)
# 조현병(정신분열병)(schizophrenia)
# 주의력결핍 과잉행동장애(Attention-Deficit Hyperactivity Disorder)
# 중증 근무력증(Myasthenia gravis)
# 지적장애(Intellectual disability)
# 지주막하 출혈(Subarachnoid hemorrhage)
# 진행성 핵상마비(progressive supranuclear palsy)
# 척수 종양(Spinal Cord tumor)
# 척수근육위축(Spinal muscular atrophy)
# 척수병증(Myelopathy)
# 척수소뇌성 운동실조증 (Spinocerebellar ataxia, SCA)
# 척추 뇌저 동맥 증후군(Vertebro-basilar artery syndrome)
# 치매(Dementia)
# 테이-삭스병 (Tay-Sachs disease)
# 틱 장애(Tic)
# 파킨슨병(Parkinson's disease)
# 편두통(Migraine)
# 편집성 인격장애(Paranoid personality disorder)
# 폐소공포증(Claustrophobia)
# 피질하 경색과 백질뇌증을 동반하는 상염색체 우성 뇌동맥질환(Cerebral Autosomal Dominant Arteriopathy with Subcortical Infarcts and Leukoencephalopathy)
# 하지불안증후군(Restless Legs Syndrome)
# 해리 장애(Dissociative disorder)
# 행동 및 충동 장애(Disruptive, impulse-control and conduct disorders)
# 헌팅톤 병(Huntington disease)
# 혈관성 치매(Vascular dementia)
# 혼수(Coma)
# 후두 신경통(Occipital Neuralgia)
# 구개열(Cleft palate)
# 구순열(Cleft lip)
# 노화된 얼굴(Aging face)
# 돌출귀(Prominent Ear)
# 두개 안면 부조화(Craniofacial dysharmony)
# 비 변형(Nose deformity)
# 선천성 손 기형(Congenital hand anomaly)
# 소이증(Microtia)
# 안면 비대칭(Facial asymmetry)
# 양안격리증(Hypertelorism)
# 취한증(Osmidrosis)
# 턱뼈 성장 이상(Anomalies of the jaw)
# 함몰 유두(Inverted nipple)
# Rh 부적합 임신(Rh Incompatibility pregnancy)
# 가와사키병(Kawasaki Disease)
# 고환 여성화 증후군(Testicular feminization syndrome)
# 과숙아, 만기 후 출산아(Post-term infant)
# 기관지폐 형성이상(Bronchopulmonary dysplasia)
# 기형종(Teratoma)
# 단심실(Single ventricle)
# 대동맥 협착(Aortic stenosis)
# 대동맥 협착증(Coarctation of aorta)
# 대동맥궁 단절(Interrupted aortic arch)
# 대혈관 전위(Transposition of great artery)
# 댄디워커 증후군(Dandy-Walker syndrome)
# 동맥간증(Truncus arteriosus)
# 동맥관 개존증(Patent ductus arteriosus)
# 라이 증후군(Reye syndrome)
# 로하드 증후군(ROHHAD Syndrome)
# 모호한 생식기(Ambiguous genitalia)
# 발살바동 동맥류 파열(Ruptured sinus of valsava aneurysm)
# 발육부전성 좌심 증후군(Hypoplastic left heart syndrome)
# 방실 중격 결손(Atrioventricular septal defect)
# 배꼽염(Omphalitis)
# 사춘기 조숙(Precocious puberty)
# 생식선 및 생식 세포의 신생물(Gonadal and germ cell neoplasma)
# 서혜부 탈장(Inguinal hernia)
# 선천성 거대결장증(Hirschsprung disease)
# 선천성 담관 폐쇄증(Congenital Atresia of Bile Ducts)
# 선천성 소장 결손, 폐쇄 및 협착(Congenital absence, atresia and stenosis of intestine)
# 선천성 수신증(Congenital hydronephrosis)
# 선천성 심장 질환(Congenital heart disease)
# 수정대혈관 전위(Corrected TGA)
# 신경모세포종(Neuroblastoma)
# 신생아 가사(Neonatal asphyxia)
# 신생아 경련(Convulsions of newborn)
# 신생아 다혈구증(Polycythemia)
# 신생아 답즙정체증(Neonatal Cholestasis)
# 신생아 호흡곤란증후군(Neonatal respiratory distress syndrome)
# 신생아 황달(Neonatal jaundice)
# 심방 중격 결손(Atrial septal defect)
# 심실 중격 결손(Ventricular septal defect)
# 알포트 증후군(Alports syndrome)
# 양대혈관 우심실 기시증(Double outlet right ventricle)
# 양방단실유입증(Double inlet ventricle)
# 엡스테인 심기형(Ebstein anomaly)
# 영아 돌연사 증후군(Sudden Infant Death Syndrome)
# 영아 비대성 유문협착증(IHPS (infantile hypertrophic pyloric stenosis))
# 영아 산통(Infantile Colic)
# 온전한 심실 중격을 가진 폐동맥 폐쇄(Pulmonary atresia with intact venticulr septum)
# 유당분해효소결핍증(Lactose intolerance)
# 융모양막염(Chorioamnionitis)
# 잠재성 이분 척추(Spina bifida occulta)
# 저신장(Short stature)
# 전폐정맥연결 이상(Total anomalous pulmonary venous connection)
# 제대 탈장(Umbilical hernia)
# 조로증(progeria)
# 척수수막류(Myelomeningoceles)
# 천식(Asthma)
# 총동맥간증(Persistent truncus arteriosus)
# 태아 알코올 증후군(Fetal alcohol syndrome)
# 팔로 사 징후(Tetralogy of Fallot with/without PA)
# 항문 폐쇄증(Imperforate anus)
# 핵황달(Kernicterus)
# 헤노호 쉰라인 자반증(Henoch-Schonlein purpura)
# 횡격막 탈장(Diaphragmatic hernia)
# 간 전이(Liver Metastasis)
# 간 혈관종(Hepatic hemangioma)
# 간경화(Liver cirrhosis)
# 간내 담석(IHD stone)
# 간디스토마(Clonorchisis sinensis)
# 간문부 담관암(Klatskin's tumor)
# 간성 뇌증(Hepatic encephalopathy)
# 간세포암(Hepatocellular carcinoma)
# 간신 증후군(Hepatorenal syndrome)
# 간염(Hepatitis)
# 간의 양성 신생물(Benign neoplasm of the liver)
# 간이식 후 상태(Liver Transplantation status)
# 게실 질환(Diverticular disease)
# 경화성 담관염(Sclerosing cholangitis)
# 궤양성 대장염(Ulcerative colitis)
# 급성 A형 간염(Acute hepatitis A)
# 급성 B형 간염(Acute hepatitis B)
# 급성 C형 간염(Acute hepatitis C)
# 급성 담낭염(Acute cholecystitis)
# 급성 충수염(Acute appendicitis)
# 급성 췌장염(Acute pancreatitis)
# 기능성 위장 장애(Functional Gastrointestinal Disorder)
# 단장 증후군(Short Bowel Syndrome)
# 담관암(Cholangiocarcinoma)
# 담낭 선근종증(Aadenomyomatosis of Gallbladder)
# 담낭 용종(GB polyp)
# 담낭암(GB cancer)
# 담석(GB stone)
# 대장 용종(Polyp of colon)
# 대장암(Colon cancer)
# 대장염(Colitis)
# 대장의 양성 종양(Benign colon tumor)
# 덤핑 증후군(Dumping syndrome)
# 독성 간염(Toxic hepatitis)
# 만성 B형 간염(Chronic hepatitis B)
# 만성 담낭염(Chronic cholecystitis)
# 만성 위염(Chronic gastritis)
# 만성 췌장염(Chronic pancreatitis)
# 말로리-바이스 증후군(Mallory-weiss Syndrome)
# 맹장염(Appendicitis)
# 메켈 게실(Meckel's diverticulum)
# 문맥색전증(Portal vein thrombosis)
# 바렛 식도(Barrett's esophagus)
# 바이러스성 장염(Viral enteritis(Rota))
# 바터 팽대부 암(AOV cancer)
# 반티 증후군(Banti syndrome)
# 반흔 탈장(Incisonal hernia)
# 버드 키아리 신드롬(Budd-Chiari syndrome)
# 변비(Constipation)
# 변실금(Fecal incontinence)
# 복강 내 출혈(Intraperitoneal Bleeding)
# 복막염(Peritonitis)
# 복부 대동맥류(Abdominal aortic Aneurysm)
# 복수(Ascites)
# 석회화 담낭(Porcelain GB)
# 셀리악병(Celiac disease)
# 소장암(Small bowel cancer)
# 소장의 혈관 장애(Vascular disorders of intestine)
# 소화관의 이물(Foreign body in alimentary tract)
# 소화불량(Dyspepsia)
# 식도 정맥류(Esophageal varices)
# 식도암(Esophageal cancer)
# 식도염(Esophagitis)
# 식도의 이물(Foreign body in esophagus)
# 식도의 평활근종(Leiomyoma of esophagus)
# 식도이완불능증(Esophageal Achalasia)
# 식중독(Foodborne illness)
# 십이지장 궤양(Duodenal ulcer)
# 십이지장염(Duodenitis)
# 아메바성 간농양(Amebic liver abscess)
# 원발성 담즙성 경화증(Primary Biliary cirrhosis)
# 위 유암종(Gastric Carcinoid Tumor)
# 위 정맥류(Gastric varices)
# 위경련(Stomach cramp)
# 위궤양(Gastric ulcer)
# 위막성 대장염(Pseudomembranous colitis)
# 위말트 림프종 (Gastric MALT lymphoma)
# 위선종(Gastric adenoma)
# 위식도 역류성 질환(Gastro-esophagus reflux disease)
# 위암(Stomach cancer)
# 위염(Gastritis)
# 위용종(Gastric polyp)
# 위장관 기질 종양(Stomach GIST)
# 위장관 출혈(Gastrointestinal hemorrhage)
# 이소성 췌장(Ectopic pancreas)
# 자가면역성 간염(Autoimmune hepatitis)
# 자극성 장 증후군(Irritable bowel syndrome)
# 장염전(Volvulus)
# 장유착(Intestine adhesions)
# 장중첩증(Intussusception)
# 장폐색(Intestinal obstruction)
# 재발성 탈장(Recurrent hernia)
# 전격성 간염(Fulminant Hepatic Failure)
# 조기 위암(Early gastric cancer)
# 직장 유암종(Rectal Carcinoid Tumor)
# 직장암(Rectal cancer)
# 직장의 양성 종양(Rectum, benign tumor)
# 진행성 위암(Advanced gastric cancer)
# 총담관 낭(Choledochal cyst)
# 총담관 담석(CBD stone)
# 충수암(appendiceal carcinoma)
# 췌장 전이암(Pancreatic metastasis)
# 췌장염(Pancreatitis)
# 치핵(Hemorrhoids)
# 카롤리병(Caroli’s disease)
# 크론병(Crohn's disease)
# 탈항(Anal prolapse)
# 항문 누공(Anal fistula)
# 항문 및 직장의 궤양(Ulcer of anus and rectum)
# 항문 열구(Anal fissure)
# 항문 주위 농양(Perianal abscess)
# 항문소양증(Pruritusani)
# 항문암(Anal cancer)
# 헬리코박터균 감염(Helicobacter pylori infection)
# 화농성 간농양(Pyogenic liver abscess)
# 흡수장애 증후군(Malabsorption Syndrome)
# WPW 증후군(Wolff-Parkinson-White syndrome)
# 결절성 다발동맥염(Polyarteritis nodosa)
# 경동맥 협착증(Carotid artery stenosis)
# 급성 관동맥 증후군(Acute Coronary Syndrome)
# 급성 류마티스성 열(Acute Rheumatic fever)
# 급성 심근경색증(Acute myocardial infarction)
# 난원공 개존증(Patent Foramen Ovale)
# 대동맥 박리(Aortic dissection)
# 대동맥류(Aortic aneurysm)
# 대동맥판막 기능부전(Aortic (valve) insufficiency)
# 대동맥판막 협착(Aortic (valve) stenosis)
# 동기능 부전 증후군(Sick sinus syndrome)
# 동맥류(Other aneurysm)
# 동맥색전증 및 혈전증(Arterial embolism and thrombosis)
# 동정맥루 기능부전(AVF malfuction)
# 레리시 증후군(Leriche Syndrome)
# 림프부종(Lymphedema)
# 발작성 상심실성 빈맥(Paroxysmal Supraventricular Tachycardia)
# 부르가다 증후군(Brugada Syndrome)
# 부정맥(Cardiac arrhythmias)
# 불안정형 협심증(Unstable angina)
# 상대정맥 증후군(Superior vena cava Syndrome)
# 서맥(Bradycardia)
# 수족냉증(Coldness of hands and feet)
# 승모판 기능부전(Mitral (valve) insufficiency)
# 승모판 협착(Mitral (valve) stenosis)
# 심계항진(Palpitations)
# 심근병증(Cardiomyopathy)
# 심근염(Myocarditis)
# 심낭 삼출 (Pericardial effusion)
# 심낭 압전(Cardiac tamponade)
# 심낭염(Pericarditis)
# 심방 세동(Atrial fibrillation)
# 심방 조동(Atrial Flutter)
# 심부정맥 색전증(Deep vein thrombosis)
# 심실 빈맥(Ventricular tachycardia)
# 심실 세동(Ventricular fibrillation)
# 심장 종양(Cardiac tumor)
# 심장 판막 질환(Valvular heart disease)
# 심장신경성 실신(Neurocardiogenic syncope)
# 오래된 심근경색증(Old myocardial infarction)
# 울혈성 심부전(Congestive heart failure)
# 잠수병(Diver's disease)
# 장간막 동맥 혈전증(Mesenteric Arterial Thrombosis)
# 장간막 정맥 혈전증(Mesenteric Venous Thrombosis)
# 저혈압(Hypotension)
# 전도 장애(Conduction disorders)
# 죽상경화증(Atherosclerosis)
# 측두동맥염(Temporal arteritis)
# 타카야수 혈관염(Takayasu’s Arteritis)
# 타코츠보 심근증(Takotsubo cardiomyopathy)
# 폐 혈전색전증(Pulmonary thromboembolism)
# 폐성 고혈압(Pulmonary hypertension)
# 하지 정맥류(Varicose veins)
# 허혈성 심질환(Ischemic heart disease)
# 혈관염(Vasculitis)
# 협심증(Angina pectoris)
# 흉곽출구 증후군(Thoracic outlet syndrome)
# 흉부 대동맥류(Thoracic aortic Aneurysm)
# 흉통(Chest pain)
# PSA 상승(Elevated PSA)
# 간질성 방광염(Interstitial Cystitis)
# 감돈포경(Paraphimosis)
# 고나트륨혈증(Hypernatremia)
# 고마그네슘혈증(Hypermagnesemia)
# 고칼륨혈증(Hyperkalemia)
# 고환 종양(Tumors of testis)
# 고환염(Orchitis)
# 고환의 염전(Torsion of testis)
# 귀두포피염(Balanoposthitis)
# 급성 간질성 신염(Acute tubulo-interstitial nephritis)
# 급성 방광염(Acute cystitis)
# 급성 신부전(Acute renal failure)
# 급성 신우신염(Acute pyelonephritis)
# 남성 불임(Male infertility)
# 낭성 신장 질환(Cystic kidney disease)
# 만성 신부전(Chronic renal failure)
# 만성 전립선염(Chronic prostatitis)
# 말기 신질환(End stage renal disease)
# 면역글로불린 A 신병증(IgA nephropathy)
# 무정자증(azoospermia)
# 무증상 세균뇨(Asymptomatic bacteriuria)
# 미세변화 신증후군(Minimal change nephrotic syndrome)
# 발작성야간혈색뇨(Paroxysmal nocturnal hemoglobinuria)
# 방광소장 누공(Vesicointestinal fistula)
# 방광암(Bladder cancer)
# 방광요관 역류(Vesicoureteral reflux)
# 방광의 신경근육 기능 장애(Neuromuscular dysfunction of bladder)
# 방광질 누공(Vesicovaginal fistula)
# 방광탈(Cystocele)
# 배뇨통(Dysuria)
# 복압성 요실금(Stress urinary incontinence)
# 부고환염(Epididymitis)
# 비임균성 요도염(Nongonococcal urethritis)
# 사구체신염(Glomerulonephritis)
# 소변 정체(Retention of urine)
# 수신증(Hydronephrosis)
# 신동맥 협착증(Renal artery stenosis)
# 신부전(Renal failure)
# 신세포암종(Renal cell carcinoma)
# 신우요관 폐색(UPJ obstruction)
# 신우요관암(Renal pelvis cancer)
# 신장 결석(Renal stone)
# 신장 이형성증(Renal dysplasia)
# 신장의 신생물(Neoplasm of the kidney)
# 신증후군(Nephrotic syndrome)
# 야뇨증(Enuresis)
# 양성 전립선 비대증(Benign prostatic hyperplasia)
# 요관 결석(Ureteral stone)
# 요관 협착(Ureteral stricture)
# 요도하열(Hypospadias)
# 요독증(Uremia)
# 요로 감염(Urinary tract infection)
# 요로결석(Urolithiasis)
# 요실금(Urinary incontinence)
# 음경 발기지속증(Priapism)
# 음경만곡증(Peyronie’s disease)
# 음경암(Penis Cancer)
# 음낭 내 부속기 염전(Intrascrotal appendage, torsion)
# 음낭수종(Hydrocele)
# 임질(Gonorrhea)
# 잠복고환증(Cryptorchidism)
# 전립선암(Prostate cancer)
# 전이성 신장암(Kidney, cancer, metastatic)
# 정계정맥류(Varicocele)
# 정자부족증(Oligospermia)
# 조루증(Premature ejaculation)
# 칼만 증후군(Kallmann syndrome)
# 포경(Phimosis)
# 혈뇨(Hematuria)
# 혈정액증(Hematospermia)
# 회음 괴저(Fournier's gangrene)
# 가진통(False labor)
# 계류 유산(Missed abortion)
# 골반 염증성 질환(Pelvic inflammatory disease)
# 과다월경(Hypermenorrhea)
# 과립막 세포종(Granulosa cell tumor)
# 난관수종(Hydrosalpinx)
# 난산(Dystocia)
# 난소 낭종(Ovarian cysts)
# 난소, 난관 이상(Disorders of ovary, fallopian tube)
# 난소암(Ovarian cancer)
# 난소의 양성 종양(Benign ovary tumor)
# 노인성 질염(Senile (atrophic) vaginitis)
# 다낭성 난소 증후군(Polycystic ovary syndrome)
# 다태아(Multifetal pregnancy)
# 단일 제대 동맥(Single Umbilical Artery)
# 만기 정상 분만(Normal full term spontaneous delivery)
# 무월경(Amenorrhea)
# 바르톨린샘의 고름집(Abscess of Bartholin's gland)
# 배란통(Ovulation pain)
# 분만 후 출혈(Postpartum hemorrhage)
# 비정상적 자궁, 질 출혈(Abnormal uterine and vaginal bleeding)
# 산욕열(Puerperal fever)
# 습관성 유산(Habitual miscarriage)
# 쌍태아 수혈 증후군(Twin to twin Transfusion Syndrome)
# 아두골반 불균형(Cephalopelvic disproportion)
# 양수과다증(Hydramnios)
# 양수과소증(Oligohydramnios)
# 양수색전증(Amniotic fluid embolism)
# 여성 불임(Female infertility)
# 외음부암(Vulvar Cancer)
# 외음질의 이물(Foreign body in vulva and vagina)
# 원발성 월경곤란(Primary dysmenorrhea)
# 월경전 증후군(Premenstrual syndrome)
# 유방 농양(Abscess of breast)
# 유방통(Mastodynia)
# 유산(Abortion)
# 유산 후 계속되는 임신(다태)(Continuing pregnancy after abortion)
# 융모막암종(Choriocarcinoma)
# 이상 태위(Malpresentation of fetus)
# 임신성 고혈압(Pregnancy-induced hypertension)
# 임신성 당뇨병(Gestational diabetes)
# 자간전증(Pre-eclampsia)
# 자간증(Eclampsia)
# 자궁 경부의 이형성증(Dysplasia of cervix uteri)
# 자궁 내 성장 지연(Intrauterine growth retardation)
# 자궁 발육부전(Hypoplasia uteri)
# 자궁 상피 내 암종(Carcinoma in situ of Cervix)
# 자궁 외 임신(Ectopic pregnancy)
# 자궁 육종(Sarcoma of Uterus)
# 자궁 탈출증(Uterine Prolapse)
# 자궁경관무력증(Incompetent internal os of cervix)
# 자궁경부암(Cervical cancer)
# 자궁내막 용종(Polyp of endometrium)
# 자궁내막 이상증식증(Endometrial hyperplasia)
# 자궁내막암(Endometrial cancer)
# 자궁내막증(Endometriosis)
# 자궁선근증(Adenomyosis)
# 자궁의 비염증성 장애(Noninflammatory disorders of uterus)
# 자궁의 평활근종(Leiomyoma of uterus)
# 전치 태반(Placenta previa)
# 절박 유산(Threatened Abortion)
# 조기 양막 파열(Premature rupture of membranes)
# 조기 진통(Preterm labour)
# 조기 폐경(Premature ovarian failure)
# 조산(Prematurity delivery)
# 질암(Vaginal Cancer)
# 칸디다성 외음질염(Candidal vulvovaginitis)
# 태반 유착증(Placenta Accreta)
# 태반 조기 박리(Abruptio placenta)
# 트리코모나스증(Trichomoniasis)
# 폐경기 및 여성의 갱년기 상태(Menopausal and female climacteric states)
# 포상기태(Hydatidiform mole)
# 회음 열상(Perineal laceration)
# 희발월경(Oligomenorrhea)
# 갈색세포종(Pheochromocytoma)
# 갑상선 결절(Thyroid nodule)
# 갑상선 미분화암(Undifferentiated thyroid cancer)
# 갑상선 수질암(Medullary thyroid cancer)
# 갑상선 여포암(Follicular thyroid cancer)
# 갑상선 유두암(Papillary Carcinoma of Thyroid )
# 갑상선기능저하증(Hypothyroidism)
# 갑상선기능항진증(Hyperthyroidism)
# 갑상선암(Thyroid cancer)
# 갑상선염(Thyroiditis)
# 갑상선중독증(Thyrotoxicosis)
# 갑상설관 낭종(Thyroglossal duct cyst)
# 고칼슘혈증(Hypercalcemia)
# 골다공증(Osteoporosis)
# 넬슨 증후군(Nelson's syndrome)
# 뇌하수체 기능 항진(Hyperfunction of pituitary gland)
# 뇌하수체 기능부전(Hypopituitarism)
# 당뇨병(Diabetes mellitus)
# 당뇨병성 족부 질환(DM foot ulcer)
# 당뇨병성 케톤산증 (Diabetic ketoacidosis)
# 부갑상선기능저하증(Hypoparathyroidism)
# 부갑상선기능항진증(Hyperparathyroidism)
# 부갑상선암(Parathyroid Cancer)
# 부신 기능부전(Adrenal insufficiency)
# 부신 종양(Adrenal tumor)
# 성선기능저하증(Hypogonadism)
# 성장호르몬 결핍증(Growth hormone deficiency)
# 여성형 유방(Gynecomastia)
# 요붕증(Diabetes insipidus)
# 유관 확장증(Mammary duct ectasia)
# 유방 상피내암(Carcinoma In Situ of Breast)
# 유방 종양(Breast mass)
# 유방암(Breast cancer)
# 유방의 미세석회화(Microcalcification of breast)
# 유방의 섬유선종(Fibroadenoma of breast)
# 유방의 엽상 종양(Benign phyllodes tumor of breast)
# 유방의 유선관 내 유두종(Intraductal papilloma of breast)
# 유선염(Mastitis)
# 인슐린 비의존성 당뇨병(Non-insulin dependent diabetes mellitus)
# 인슐린 의존성 당뇨병(Insulin-dependent diabetes mellitus)
# 자가면역성 갑상선염(Autoimmune thyroiditis)
# 저혈당증(Hypoglycemia)
# 점액수종 혼수(Myxoedema coma)
# 카르시노이드 증후군(Carcinoid syndrome)
# 쿠싱 증후군(Cushing's syndrome)
# 흉선암(Thymus Cancer)
# 18번 염색체 단완결실 증후군(18p monosomy)
# 18번 염색체 장완결실 증후군 (18q monosomy)
# 22번 염색체 장완 미세결실 증후군(CATCH22)
# 4번 염색체 단완결실 증후군(Wolf-Hirschhorn syndrome)
# ARC 증후군(Arthrogryposis, Renal dysfunction, Cholestasis, ARC syndrome)
# Haw River 증후군(Dentatorubro-Pallidoluysian atrophy(DRPLA))
# XXX 증후군(XXX syndrome)
# XYY 증후군(XYY syndrome)
# 결절성 경화증 (Tuberous sclerosis)
# 골형성부전증(Osteogenesis imperfecta)
# 누난 증후군 (Noonan syndrome)
# 니만-피크병(Niemann-Pick disease)
# 다운 증후군 (Down syndrome)
# 러셀 실버 증후군 (Russell-Silver syndrome)
# 레트 증후군 (Rett syndrome)
# 루빈스타인 테이비 증후군 (Rubinstein-Taybi syndrome)
# 모세혈관 확장성 운동실조 증후군 (Ataxia-telangiectasia syndrome)
# 묘성 증후군(Cri du Chat syndrome)
# 무치아증(Anodontia)
# 바르덴부르크 증후군(Waardenburg syndrome)
# 베스트 난황형 황반부 이영양증 (Best vitelliform macular dystrophy)
# 베커형 근이영양증(Becker muscular dystrophy)
# 베크위트-위드만 증후군(Beckwith-Wiedemann syndrome)
# 본히펠린다우 증후군 (Von Hippel-Lindau syndrome)
# 부신백질이영양증(Adrenoleukodystrophy)
# 사이트린 결핍(Citrin deficiency)
# 산필리포 증후군(Sanfilippo Syndrome)
# 새열 낭종(Branchial Cyst)
# 선천성 갑상선기능저하증(Congenital hypothyroidism)
# 선천성 기형(Congenital malformation)
# 선천성 부신과다 형성증(Congenital adrenal hyperplasia)
# 스미스-마제니스 증후군 (Smith-Magenis syndrome, SMS)
# 스티클러 증후군(Stickler syndrome)
# 슬라이 증후군(Sly Syndrome)
# 시트룰닌혈증(Citrullinemia)
# 안드로겐 불감성 증후군 (Androgen insensitivity syndrome(AIS))
# 에드워드 증후군 (Edwards syndrome)
# 에이퍼트 증후군 (Apert syndrome)
# 엔젤만 증후군(Angelman syndrome)
# 엘러스-단로스 증후군 (Ehlers-Danlos syndrome)
# 연골무형성증(Achondroplasia)
# 윌름즈 종양(Wilms Tumor)
# 윌리암스 증후군 (Williams syndrome)
# 차지 증후군(CHARGE Syndrome)
# 카르니틴 팔미토일 전환효소 결핍증 2형(Carnitine Palmitoyltransferase II Deficiency)
# 코넬리아드랑게 증후군 (Cornelia de Lange syndrome)
# 크루존 증후군(Crouzon syndrome)
# 터너 증후군 (Turner syndrome)
# 트리처 콜린스 증후군 (Treacher-Collins syndrome)
# 파브리병(Fabry disease)
# 파이퍼 증후군 (Pfeiffer syndrome)
# 파타우 증후군(Patau syndrome)
# 페닐케톤뇨증(Phenylketonuria)
# 폼페병(Pompe disease)
# 프라더 윌리 증후군 (Prader-Willi syndrome)
# 프로피온산증(Propionic acidemia)
# 고산병(Mountain sickness)
# 기뇌증(Pneumocephalus)
# 대사성 산증(Metabolic Acidosis)
# 대사성 알칼리증(Metabolic Alkalosis)
# 독성 쇼크 증후군(Toxic shock syndrome)
# 벌에 쏘였을 때(Bee bite)
# 악성 고열증(Malignant hyperthermia)
# 약물 알레르기(Drug allergy)
# 열 피로(heat exhaustion)
# 열사병(Heat stroke)
# 이물질에 의한 기도 막힘(Airway obstruction)
# 익수(Submersion)
# 일산화탄소 중독(Carbon monoxide-poisoning)
# 저나트륨혈증(Hyponatremia)
# 저마그네슘혈증(Hypomagnesemia)
# 저체온증(Hypothermia)
# 저칼륨혈증(Hypokalemia)
# 저칼슘혈증(Hypocalcemia)
# 혈관부종(Angioedema)
# 호흡성 산증(Respiratory Acidosis)
# 호흡성 알칼리증(Respiratory Alkalosis)
# 화상(Burn)
# 거대적혈모구빈혈(Megaloblastic anemia)
# 골수증식종양(Myeloproliferative neoplasm)
# 골수형성이상증후군(Myelodysplastic syndromes)
# 과오종(Hamartoma)
# 급성골수성백혈병(Acute myeloid leukemia)
# 급성림프모구백혈병(Acute lymphoblastic leukemia)
# 기저세포 암종(Basal cell carcinoma)
# 다발골수종(Multiple myeloma)
# 단세포군감마글로불린병증(Monoclonal gammopathy of undetermined significance)
# 랑거한스세포 조직구증식증(Langerhans cell histiocytosis)
# 린치 증후군(Lynch Syndrome)
# 림프종(Lymphoma)
# 만성골수백혈병(Chronic myeloid leukemia)
# 만성림프구백혈병(Chronic lymphocytic leukemia)
# 면역결핍증(Immunodeficiency disease)
# 면역혈소판감소증(Immune thrombocytopenia)
# 미세혈관병용혈빈혈(Microangiopathic hemolytic anemia)
# 백혈병(Leukemia)
# 버킷 림프종(Burkitt Tumor)
# 범혈구감소증(Pancytopenia)
# 부신암(Adrenal gland cancer)
# 비소세포성 폐암(Non-small cell lung cancer)
# 비장암(Spleen Cancer)
# 비호지킨 림프종(Non-Hodgkin lymphoma)
# 소세포성 폐암(Small cell lung cancer)
# 소적혈구빈혈(Microcytic anemia)
# 순수적혈구무형성(Pure red cell aplasia)
# 아밀로이드증(Amyloidosis)
# 악성 종격동 종양(Malignant mediastinal tumor)
# 악성 중피종(Malignant mesothelioma)
# 악성 흉막 삼출(Malignant pleural effusion)
# 악성 흑색종(Malignant melanoma)
# 양성 종격동 종양(Benign mediastinal tumor)
# 연부조직 전이(Soft tissue metastatic)
# 용혈빈혈(Hemolytic anemia)
# 원발부위 불명암(Cancer of Unknown Primary Site)
# 원발성 중추신경계 림프종(Primary CNS lymphoma)
# 유방 파제트병 (Pagets disease of the Breast)
# 유잉육종(Ewing sarcoma)
# 유전구형적혈구증(Hereditary spherocytosis)
# 응고 장애(Disorders of coagulation)
# 이식편대숙주질환(Graft-versus-host reaction or disease(GVHD))
# 자가면역 질환(autoimmune diseasse)
# 자가면역용혈질환(Autoimmune hemolytic disease)
# 재생불량빈혈(Aplastic anemia)
# 전이 암(Metastatic cancer)
# 조혈모세포 이식(Stem cell transplantation)
# 지중해빈혈(Thalassemia)
# 철결핍빈혈(Iron deficiency anemia)
# 췌장암(Pancreatic cancer)
# 카포시 육종(Kaposi's sarcoma)
# 캐슬만병(Castlemans disease)
# 파종혈관내응고(Diffuse or disseminated intravascular coagulation)
# 폐 전이(Lung Metastasis)
# 폐암(Lung cancer)
# 포르피린증(Porphyria)
# 폰빌레브란트병(Von Willebrand disease)
# 피부섬유육종(Dermatofibrosarcoma )
# 피부암(Skin cancer)
# 피부의 양성 종양(Benign skin tumor)
# 한랭글로불린혈증(Cryoglobulinemia)
# 항인지질 항체 증후군(Antiphospholipid antibody syndrome)
# 혈소판 이상(Disorders of the platelets)
# 호중구감소증(Neutropenia)
# 호지킨 림프종(Hodgkin lymphoma)
# 근단 주위 농양(Periapical abscess with sinus)
# 만성 치주염(Chronic periodontitis)
# 매복 사랑니(Impacted teeth)
# 발육성 치성 낭종(Developmental odontogenic cysts)
# 설통(Glossodynia)
# 치근낭(Radicular cyst)
# 치아 우식증[충치](Dental Caries)
# 치열 궁 관계 이상(Anomalies of dental arch relationship)
# 치은염(Gingivitis)
# 치조골염(Alveolar ostitis)
# 치주 농양(Periodontal abscess)
# 턱관절 탈구(Luxation of the mandible)
# 턱의 기타 낭증(Other cysts of jaw)
# 간찰성 홍반(Erythema intertrigo)
# 건선(Psoriasis)
# 광선 각화증(Actinic Keratosis)
# 국소 다한증(Localized hyperhidrosis)
# 기미(Melasma)
# 기저귀 피부염(Diaper (napkin) dermatitis)
# 내향성 손발톱(Ingrowing nails)
# 농가진(Impetigo)
# 다모증(Excessive hair growth)
# 동상(Frostbite)
# 동전모양 습진(Nummular Eczema)
# 두드러기(Urticaria)
# 딸기코(Rosacea)
# 땀띠(Miliaria)
# 만성 단순 태선(Lichen simplex chronicus)
# 만성 두드러기(Chronic urticaria)
# 모공성 각화증(Keratosis pilaris)
# 모낭염(Folliculitis)
# 모반(Nevus)
# 무모증(Atrichia pubis)
# 무좀(Tinea pedis)
# 백반증(Vitiligo)
# 봉와직염(Cellulitis)
# 비듬(Dandruff)
# 비립종(Milium)
# 상피내 신생물(IN SITU NEOPLASMS)
# 색소 세포성 모반(Melanocytic nevus)
# 선천성 색소결핍증(Congenital Albinism)
# 수부 습진(Hand Eczema)
# 습진(Eczema)
# 아토피성 피부염(Atopic dermatitis)
# 안검황색종(Xanthelasma)
# 안면 홍조증(Hot flush)
# 약물 발진(Drug Eruption)
# 어루러기(Pityriasis versicolor)
# 어린선(Ichthyosis)
# 여드름(Acne)
# 오타 모반(Ota like Melanosis)
# 옴(Scabies)
# 욕창(Skin defect (and/or) soft tissue defect)
# 접촉 피부염(Contact dermatitis)
# 조갑 이영양증(Nail dystrophy)
# 조갑백선(Tinea unguium)
# 주근깨(Freckle,Ephelis)
# 쥐젖(Soft fibroma)
# 지루성 피부염(Seborrheric dermatitis)
# 천포창(Pemphigus)
# 켈로이드(Keloid)
# 콜린성 두드러기(Cholinergic urticaria)
# 탈락 피부염(Exfoliative dermatitis)
# 탈모증(Alopecia)
# 태열()
# 티눈 및 굳은살(Corns and callosities)
# 파라핀종(Paraffinoma)
# 편평 태선(Lichen Planus)
# 표피낭종(Epidermal cyst)
# 피부 농양(Cutaneous abscess)
# 피부건조증(Xerosis cutis)
# 피부염(Dermatitis)
# 한관종(Syringoma)
# 한랭 두드러기(Cold urticaria)
# 한선염(Hidradenitis suppurativa)
# 화염상 모반(Nevus flammeus)
# 흉터(Scar)
# 가습기 살균제 연관 폐질환(Humidifier disinfectant-associated lung injury)
# 객혈(Hemoptysis)
# 공기가슴증(기흉)(Pneumothorax)
# 규폐증(Silicosis)
# 급성 기관지염(Acute bronchitis)
# 기관 협착(Stenosis of trachea)
# 기관지확장증(Bronchiectasis)
# 낭종성 폐질환(Cystic Lung Disease)
# 농흉(Pyothorax, Empyema)
# 늑막염(Pleurisy)
# 만성 기관지염(Chronic bronchitis)
# 만성 기침(Chronic cough)
# 만성 폐쇄성 폐질환(Chronic obstructive pulmonary disease)
# 만성 폐질환(Chronic lung disease)
# 미만성 간질성 폐질환(Diffuse Interstitial lung disease)
# 성인 호흡곤란 증후군(Adult respiratory distress syndrome)
# 재발성 천명(Recurrent wheeze)
# 종격동염(Mediastinitis)
# 진폐증(Pneumoconiosis)
# 태변 흡인 증후군(Meconium aspiration syndrome)
# 특발성 폐섬유화증(Idiopathic pulmonary fibrosis)
# 폐 농양(Abscess of lung)
# 폐결절(Pulmonary nodule)
# 폐기종(Emphysema)
# 폐렴(Pneumonia)
# 폐렴간균에 의한 폐렴 (Klebsiella pneumoniae infection)
# 폐부종(Pulmonary edema)
# 흉막 삼출(Pleural effusion)
# 각막 부종(Corneal Edema)
# 림프관종(Lymphangioma)
# 설소대 단축증(Tongue tie)
# 성인형 스틸병(Adult-Onset Stills disease)
# 쇼그렌 증후군(Sicca syndrome (Sjogren))
# 악액질(Cachexia)
# 음식 알레르기(Food allergy)
# 전신 홍반성 낭창(Systemic lupus erythematosus)
# 처그 스트라우스 증후군(Churg strauss syndrome)
# 침샘염(Sialoadenitis)
#
# 증상 리스트:
# 기침
# 가래
# 열
# 빈호흡
# 콧물
# 코막힘
# 청색증
# 안구혼탁
# 눈의 충혈
# 눈물흘림
# 눈의 통증
# 시력 감소
# 눈부심
# 황달
# 기운없음
# 오한
# 복부 통증
# 오심
# 설사
# 압통
# 구토
# 간비대
# 피부염증
# 발진
# 열감
# 환부 부종
# 목의 통증
# 삼키기 곤란
# 두통
# 안면홍조
# 권태감
# 식욕부진
# 정신 지체
# 태아 저체중
# 무증상
# 청력장애
# 난청
# 궤양
# 피로감
# 눈꼽
# 눈의 자극감
# 눈의 피로
# 객혈
# 체중감소
# 근육경련
# 뼈의 변형
# 관절통
# 복부팽만감
# 빈맥
# 발한
# 복수
# 시야장애
# 눈운동신경마비
# 혼수
# 졸림
# 목 주변 부종
# 고름
# 피부궤양
# 통증 없는 부종
# 발가락 사이 갈라짐
# 손,발톱이 갈라짐
# 피부 각질
# 피부소양감
# 뇌염증상
# 뇌전증 발작
# 호흡곤란
# 근육강직
# 치매
# 이상행동
# 기억장애
# 입 주변 부종
# 입술 갈라짐
# 소양감
# 작열감
# 물집
# 피부색 변화
# 근육통
# 감기 증상
# 피부 긴장도 저하
# 탈수
# 악취
# 배뇨곤란
# 비정상적 질 분비물
# 배뇨 시 통증
# 경부 림프절병증
# 비정상적 질출혈
# 복부 불편감
# 경련
# 성격의변화
# 경부 강직
# 정신 혼미
# 의식 저하
# 방향감각 상실
# 림프 부종
# 환부 통증
# 의식 변화
# 언어장애
# 딱지
# 반점
# 보챔
# 체모감소
# 눈이 무거운 느낌
# 박동성 통증
# 뇌압상승증상
# 가슴 통증
# 결막염
# 얼굴부종
# 단백뇨
# 수면장애
# 신부전
# 수막자극증상
# 안구내 출혈
# 간부전
# 소화불량
# 사망
# 환부의 분비물
# 생식기 궤양
# 저혈압
# 관절염
# 복시
# 요정체
# 장폐색
# 신경 마비
# 안검하수
# 근육마비
# 우울
# 반상출혈
# 괴사
# 검은 점
# 결절
# 사마귀 위 털이 많음
# 색소 침착
# 적색의 각질화된 피부
# 재채기
# 눈 주변 부종
# 부정맥
# 말초 신경장애
# 딸기혀
# 편도선 비대
# 무균성 뇌막염
# 이완성 마비
# 무호흡
# 서맥
# 혈변
# 저체온
# 기민상태
# 신경과민
# 다뇨
# 요독증
# 잔변감
# 천명음
# 점상 출혈
# 장액성 분비물
# 어지러움
# 덩어리가 만져짐
# 골반 통증
# 보행이상
# 요통
# 대변에 벌레 관찰됨
# 멍
# 빈혈
# 혈뇨
# 전신 부종
# 자반증
# 고혈압
# 낮 시간대의 졸음
# 변비
# 악취가 나는 설사
# 귀의 통증
# 감각 이상
# 발적
# 생식기 부종
# 잔뇨감
# 생식기 통증
# 혈소판감소
# 복부경련
# 손,발톱이 두꺼워짐
# 급성 신부전
# 회음부의 작은 돌기
# 생식기 출혈
# 하얀 반점
# 구취
# 운동장애
# 건망증
# 인지장애
# 온몸이 떨림
# 고막 충혈
# 비웃는 듯한 표정
# 후궁반장
# 관절 운동성 감소
# 심부전
# 소변량 감소
# 말초 통증
# 말초의 허혈
# 저림
# 코플릭 반점
# 목소리 변화
# 악성종양발생
# 가슴 두근거림
# 출혈 경향성
# 철결핍성 빈혈
# 근력 약화
# 하지의 근력약화
# 불면증
# 눈가 및 이마 주름
# 골다공증
# 이마의 주름
# 코 옆과 입꼬리 주름
# 복부비만
# 전신 통증
# 수면 무호흡
# 심혈관계 증상
# 불임
# 천식
# 피부 건조
# 위장관 출혈
# 간성뇌증
# 성욕감퇴
# 감정 변화
# 불안
# 이명
# 고막에 수포형성
# 이물감
# 종양부위 부종
# 구강궤양
# 턱의 통증
# 치아 흔들림
# 이폐색감
# 경부 운동 제한
# 화농성 비루
# 안면통
# 후각 감소
# 후비루
# 후각장애
# 귀에서 냄새가 남
# 귀 상부가 두피에 매몰됨
# 축 늘어짐
# 비출혈
# 코골이
# 목의 이물감
# 구강호흡
# 산만함
# 손떨림
# 지속적인 애성
# 이중음성
# 음성피로
# 고음에서의 분열
# 몽유병
# 발기부전
# 의식 불명
# 만성 부비동염
# 안구진탕
# 안면마비
# 노란 이물질
# 헛기침
# 어깨의 통증
# 어깨 움직임의 제한
# 굽은 등
# 손의 통증
# 마찰음
# 무감각
# 엉덩이 통증
# 관절의 경직
# 발끝으로 설 수 없음
# 손가락 운동장애
# 발 굴곡 운동의 제한
# 근위축
# 손상 부위 출혈
# 하지부종
# 손상 부위 통증
# 다리변형
# 오리걸음
# 귀두가 울혈됨
# 다리의 길이가 틀림
# 다리가 잘 안 벌어짐
# 무릎 부위 부종
# 무릎 부위 통증
# 병적골절
# 뼈의 통증
# 뻣뻣함
# 어깨 잡음
# 뼈의 기형
# O자 다리
# 창백
# 새가슴
# 무맥
# 마비
# 방사통
# 관절 구축
# 종아리 근육의 비대
# 척추 측만
# 발이 안쪽을 향해 걸음
# 양무릎사이 벌어짐
# 팔의 통증
# 양반다리로 앉기힘듬
# 안구돌출
# 머리모양 변형
# 광대뼈 위치 이상
# 다른 선천성 기형
# 다발성 관절염
# 손마디가 뻣뻣해짐
# 발의 통증
# 굳은 살
# 발가락의 변형
# 관절잡음
# 엄지 발가락의 돌출
# 척추와 허리 디스크
# 발바닥 피부 두꺼워짐
# 관절 불안정증
# 손가락의 변형
# 혈전증
# 손발가락이 6개 이상
# 암 부위별로 다름
# 흉쇄 유돌근의 몽우리
# 사경
# 안면 변형
# 안쪽 발이 튀어 나옴
# 염좌
# 신발 안쪽이 주로 닳음
# 발 안쪽 아치의 소실
# 편두통
# 손가락 힘이 약해짐
# 손상부위 촉각 소실
# 파열음
# 파열부위 오목해짐
# 저작장애
# 부정교합
# 치아의 탈락
# 안면부 열상
# 발음 이상
# 개 폐구 장애
# 안면부 출혈
# 안구 이상
# 다리 통증
# 사지 마비
# 배뇨장애
# 활력징후 이상
# X자 다리
# 갈퀴족지
# 자세이상
# 파행
# 하지 마비
# 손목에 심한 붓기와 통증
# 사지 부종
# 팔의 길이가 달라짐
# 피부경화
# 레이노이드 현상
# 주먹을 쥐기 힘듬
# 남성의 여성형 유방
# 근긴장의 이상
# 고환 위축
# 자율신경장애
# 근골격계 이상
# 어깨근육 약화
# 괄약근 기능 이상
# 경직
# 배변장애
# 상지 마비
# 중심시력감소
# 암점
# 주변시야손상
# 눈꺼풀 처짐증
# 유루증
# 황반부종
# 사물이 찌그러져 보임
# 광시증
# 비문증
# 터널시야
# 야맹
# 안구증대
# 동공산대
# 동공이 흰빛으로 반짝임
# 사시
# 사물이 두개로 보임
# 눈 감을 때 번쩍거림
# 부유물이 보임
# 증상의 일중변동
# 색맹
# 색깔이 퇴색해보임
# 홍채가 흔들거림
# 앞이 뿌옇게 보임
# 물집성 표피 박리
# 안구건조
# 피부 및 점막의 염증
# 눈비빔
# 안검내반
# 약시
# 대비감 감소
# 각막 위로 결막 침범
# 광과민성
# 글자가 휘어져보임
# 실명
# 의심
# 반복적인 동작
# 학습장애
# 지남력 장애
# 비현실감
# 병원 쇼핑
# 질병에 대한 공포
# 약물남용
# 대인관계 어려움
# 조절할 수 없는 충동감
# 자살의 위험
# 망상
# 판단력장애
# 무관심
# 숨막히는 느낌
# 가슴 답답
# 얼굴이 화끈거림
# 죽음에 대한 공포
# 흉부압박감
# 손
# 발 감각 저하
# 근육긴장
# 눈꺼풀의 떨림
# 근육의 뒤틀림
# 환청
# 환각
# 입수면기의 환각
# 수면 마비
# 탈력발작
# 낮은 자존감
# 에너지가 적음
# 우유부단함
# 비관주의
# 초조함
# 흥분
# 읽기,쓰기 능력 부족
# 뇌출혈
# 반신마비
# 무의지증
# 편측 사지의 감각소실
# 운동 실어증
# 반사 이상
# 호르몬변화
# 무의식
# 생리불순
# 질의 건조함
# 성선 기능 저하증
# 시신경염
# 성기능 장애
# 시림
# 얼굴형태의 이상
# 떨림(진전)
# 이상한 소리를 냄
# 비정상적인 움직임
# 사지의 창백한 현상
# 말단비대
# 말더듬
# 고정된 믿음
# 거짓 증상 호소
# 나쁜 품행
# 야만적 행위
# 직무 태만
# 사회성 부족
# 저체중
# 낮은 지능
# 행동장애
# 긴장
# 실신
# 격동적 움직임
# 혼돈
# 충동 조절 어려움
# 충동적 도벽
# 애착 상대와 분리 거부
# 와해된 행동
# 와해된 언어
# 피해망상
# 환시
# 거칠어진 피부
# 수면 후에도 피로함
# 빈뇨
# 서동
# 자세 불안정
# 혀의 통증
# 섬망
# 무월경
# 음식섭취 거부
# 왜곡된 신체상
# 폭식
# 자제력 상실 두려움
# 가학증
# 노출증
# 관음증
# 접촉도착증
# 피학증
# 비정상적 성적 기호
# 소아기호증
# 인내심이 부족함
# 대화에 불쑥 끼어듬
# 수유 곤란
# 유두부종
# 수면 시작이 어려움
# 수면 중 이상한 행동
# 수면 주기의 변화
# 수면 유지가 어려움
# 수면 중 보행
# 깨어나면 기억하지 못함
# 태아
# 신생아의 정신 장애
# 실행증
# 갈색 피부 반점
# 체중증가
# 가슴 쓰림
# 구강건조
# 감각 과민
# 청각과민
# 미각이상
# 실인증
# 조급증
# 반사회적 인격장애
# 금단증상
# 사고의 비약
# 말을 많이 함
# 높아진 자존심
# 읽기 자체의 문제
# 읽으려 하지 않음
# 변실금
# 장마비
# 서호흡
# 삶에 대한 흥미 상실
# 오후 우울감 완화
# 간기능 저하
# 이성의 옷을 착용함
# 연속동작의 느림
# 강박증
# 낮은 학업 성취
# 편마비
# 사회적 고립
# 상동적 행동
# 희망이 없는 느낌
# 걸핏하면 눈물지음
# 무논리증
# 무욕증
# 정서적 둔마
# 손발을 계속 움직임
# 정서장애
# 심정지
# 빛이나 소리 공포증
# 원한
# 질투
# 권리를 강하게 주장
# 좁은 공간에서의 불안감
# 이인증
# 정체감 혼란 및 변형
# 정서 및 행동의 일탈
# 위험한 행동 반복
# 무도증
# 치아발달장애
# 입술
# 입천장의 기형
# 아래 눈꺼풀이 불룩함
# 볼
# 눈주위 움푹 꺼짐
# 볼이 처짐
# 이중턱
# 펴진 귓바퀴
# 코가 삐뚤어짐
# 열수
# 다지증
# 합지증
# 귀 모양의 변형
# 얼굴 중심선이 안맞음
# 한쪽 입 꼬리의 상승
# 삐뚤어진 눈
# 코
# 입
# 눈 사이가 멀어보임
# 코의 기형 동반
# 옷 액와 부분 변색
# 겨드랑이 악취
# 얼굴모양변화
# 함몰유두
# 비장비대
# 폐출혈
# 점막변화
# 자궁이 없음
# 원형
# 타원형의 탈모
# 질은 없거나 짧은 맹관
# 태아 심박동수 이상
# 흉곽 팽윤
# 호기의 증가
# 저산소증
# 고탄산증
# 무산소 발작
# 운동 시 호흡곤란
# 무뇨
# 발육부전
# 폐동맥 고혈압
# 쇼크
# 심인성 쇼크
# 대사성 산증
# 위장관의 허혈
# 저심박출량
# 심잡음
# 식욕증가
# 사춘기 지연
# 부분적 음순융합
# 음핵비대
# 미소음경(micropenis)
# 외부 생식기가 모호함
# 폐부종
# 심방 부정맥
# 배꼽의 고름 및 피
# 남: 9세 전 2차 성징
# 여: 8세 전 2차 성징
# 음낭 부종
# 회색변
# 진한 소변색
# 흑색변
# 초록색 구토
# 농신증
# 다발성 장기부전 증상
# 불규칙호흡
# 저혈당
# 지방변
# 함몰가슴
# 놀람반사의 약화
# 잦은 상기도 감염
# 반복되는 폐렴
# 호흡기감염
# 각막 이상
# 신증후군
# 수정체 이상
# 망막 이상
# 만성 신부전
# 돌연사
# 영양 불량
# 위의 연동운동이 보임
# 분출성 구토
# 발작적인 울음
# 비정상적인 진통
# 표준 신장의 3%이하
# 탈장 돌출
# 배꼽이 솟음
# 손가락으로 밀면 들어감
# 탈장 부위의 통증
# 탈장
# 모발 탈색
# 뇌수종
# 신생아의 기형
# 몸살
# 복벽이 움푹 들어감
# 포만감
# 담도감염
# 복부 압박 증상
# 배변습관의 변화
# 점액변
# 트림
# 산통
# 토혈
# 당뇨
# 옆구리 통증
# 문맥성고혈압
# 항문 통증
# 항문출혈
# 복부의 박동감
# 경정맥 확장
# 피부홍조
# 흡수장애
# 침 분비 증가
# 식후 불쾌감
# 잦은 딸꾹질
# 두드러기
# 늑막삼출
# 백혈구 증가
# 위염
# 뇌부종
# 치핵의 탈출
# 항문주위 염증
# 십이지장궤양
# 위궤양
# 요관 폐쇄
# 헛배
# 저혈량 쇼크
# 동정맥루 잡음 약화
# 피부균열
# 심실 부정맥
# 심실세동
# 환부 냉감
# 말초부종
# 울혈성 심부전
# 심음 감소
# 야뇨증
# 관련 장기의 일시적 기능장애
# 폐색전
# 성대 이상
# 방광 팽만
# 야간뇨
# 긴박뇨
# 갈증
# 고환 불쾌감
# 고환에 낭이 만져짐
# 탁한 소변
# 산혈증
# 성생활이 힘듦
# 면역기능 이상
# 정맥혈전
# 분뇨
# 소변이 샘
# 질에서 소변이 나옴
# 소변을 볼 수 없음
# 요로감염
# 신장 발육부전
# 납작한 코
# 축 쳐진 귀
# 거품있는 소변
# 수면 중 소변을 봄
# 지연뇨
# 정상적인 성생활 불가능
# 요도가 아랫쪽에 위치
# 지속 발기
# 음경이 휘어짐
# 요도 불쾌감
# 음낭이 잘 발달하지 않음
# 음낭이 작아 보임
# 뼈 전이
# 사정이 일찍 됨
# 회음부 불쾌감
# 피가 정액에 나옴
# 불규칙적 진통
# 유방의 퇴행
# 커지지 않는 자궁
# 성조숙증
# 희발월경
# 여드름
# 다모증
# 이슬
# 갱년기 증상
# 습관성 유산
# 양수의 감소
# 분만 지연
# 자궁 수축
# 질식
# 태아 뼈,근육의 기형
# 탯줄의 압박
# 임신중 배의 크기가 줄어듦
# 양막 유착
# 태반의 조기 박리
# 월경과다
# 유방 통증
# 유방의 멍울
# 태동의 위치 이상
# 고혈당
# 임신 주수보다 작은 배
# 달걀 위에 앉아있는 느낌
# 질 밖으로 빠지는 느낌
# 염증 장애에 따라 다양
# 태아의 하강감
# 아랫배가 뭉침
# 거대자궁
# 임신 오조증
# 회음부의 파열
# 갑상선이 단단해짐
# 갑상선 비대
# 추위를 못견딤
# 성대마비
# 더위를 못 견딤
# 척추 후만
# 골절
# 신장 감소
# 거인증
# 다식
# 다음
# 손,발,겨드랑이 발한
# 얼굴에 털이 자람
# 남성스러운 목소리
# 유방의 과다 성장
# 성기크기 감소
# 유방 크기의 감소
# 생리량 감소
# 겨드랑이 멍울
# 침침함
# 공복감
# 목 뒷부분의 지방축적
# 온몸의 잔털
# 가늘어지는 팔다리
# 붉고 얇은 피부
# 달모양의 둥근 얼굴
# 음낭에 없는 고환,부고환
# 잦은 감염
# 4,5번째 손가락 굽음
# 근시
# 중이염소견
# 검붉은 색 피부
# 습진
# 심근손상
# 아나필락시스
# 차갑고 축축한 피부
# 과호흡
# 림프절 농양
# 스푼형 손톱
# 점 안에 다른 색 피부
# 담석
# 흉수
# 구각염
# 설염
# 잇몸 위축
# 낭종
# 심부정맥혈전증
# 구내염
# 잇몸염증
# 치근단 부위 부종
# 이가 시림
# 치아 벌어짐
# 치아 통증
# 치아가 솟은 느낌
# 신생아-백색의 결절
# 하악전돌
# 인설
# 뿔 모양의 병변
# 육아조직
# 촘촘하게 난 털
# 코의 모공이 커짐
# 붉은 색소 침착
# 닭살
# 면포
# 털이 동반되기도 함
# 음모가 적거나 없음
# 두피 건조
# 눈,뺨 주위 작은 낭종
# 피부가 두꺼워짐
# 태선화
# 눈 주위 노란 반점
# 얼굴 한쪽의 반점
# 미세반점의 군집
# 미란
# 상처보다 넓게 자람
# 울퉁불퉁한 상처
# 불규칙한 반흔
# 분홍색의 반흔
# 모발이 가늘어짐
# 이마가 넓어짐
# 각질이 딱딱해짐
# 상처가 넓어짐
# 거품이 섞인 가래
# 사래걸림
# 곤봉지
# 화농성 객담
# 검은색 가래
# 폐기능저하
# 혀끝이 w모양
# 얼굴의 나비모양 홍반

# %% [markdown]
# # 모델 학습 및 결과

# %%
# 입력 증상 - 단어로 입력해야함
input_text =  "기침"

# 예시 데이터
sentences = result_lists

# 모델 학습
model = Word2Vec(sentences, vector_size=150, window=5, min_count=5, workers=4, sg=1)

# '열'에 대한 상위 5개 유사 단어 찾기
similar_words = model.wv.most_similar(input_text, topn=300)

# 질병 데이터만 추출하기 위한 질병 목록 (예시)
diseases = disease_list

# 질병 목록에 있는 단어들만 필터링하여 저장
disease_similar_words = [(word, similarity) for word, similarity in similar_words if word in disease_list][:5]

print(disease_similar_words)
# Out:
# [('후두암(Larynx  cancer)', 0.9464125037193298), ('코로나-19(COVID-19)', 0.9461971521377563), ('폐암(Lung cancer)', 0.9367063045501709), ('폐결핵(Pulmonary tuberculosis)', 0.9362741708755493), ('지역사회성 폐렴(Community acquired pneumonia)', 0.9341733455657959)]

# %% [markdown]
# # 문장형 도전
# 더 정확한 결과를 위해 수정 중

# %%
# Okt 형태소 분석기 초기화
okt = Okt()

# 분석할 문장
sentence_input = "두통이 너무 심해서 몸살이 난 것 같아 기침이 난다"

# 문장을 형태소 분석하여 토큰화
tokens = okt.morphs(sentence_input)

# 모델과 질병 데이터를 이용해 문장의 토큰 중에 질병 목록에 있는 단어들과 가장 유사한 단어 찾기
similar_diseases = []

for token in tokens:
    if token in model.wv.key_to_index:  # 모델이 학습한 단어인지 확인
        # 해당 토큰과 유사한 단어들 중에서 질병 목록에 있는 단어들만 추출
        similar_words = model.wv.most_similar(token, topn=300)
        for word, similarity in similar_words:
            if word in diseases:  # 질병 목록에 있는 단어인지 확인
                similar_diseases.append((word, similarity))
                break  # 가장 유사한 질병 하나만 추가하고 다음 토큰으로 넘어감
        print(token)

# 유사한 질병들 중 유사도가 높은 순으로 정렬
similar_diseases = sorted(similar_diseases, key=lambda x: x[1], reverse=True)

# 가장 유사한 질병 5개 출력
print(similar_diseases[:5])
# Out:
# 두통
# 몸살
# 기침
# [('말기 신질환(End stage renal disease)', 0.9946784973144531), ('바이러스성 뇌수막염(Viral meningitis)', 0.9778353571891785), ('후두암(Larynx  cancer)', 0.9454103708267212)]
